# %% [markdown]
# notebook is sm_ont-process_reads
#
#
# envs used = nanofilt, n50, minimap2, samtools, mosdepth, samtools, mosdepth, cutesv

# %%
import os
from pathlib import Path
import pandas as pd

# %%
proj_dir = "/master/nplatt/sm_nanopore"
ref_fas = "{}/data/genome/GCA_000237925.5.fa".format(proj_dir)
Path("{}/results".format(proj_dir)).mkdir(parents=True, exist_ok=True)

# %%
samples = [ "smor", 
            "smle_pzq_es",
            "smle_pzq_er",
            "smbre", 
            "smeg"        ]

# %%
os.chdir("{}/results".format(proj_dir))

# %% [markdown]
# ## Filter and map raw reads

# %%
#all raw reads are provided in results/raw_data

# %%
Path("{}/results/nanofilt".format(proj_dir)).mkdir(parents=True, exist_ok=True)
os.chdir("{}/results/nanofilt".format(proj_dir))

# %%
for sample in samples:
    raw_fq = "{}/results/raw_reads/{}.raw_pass.fastq".format(proj_dir, sample)

    !~/anaconda3/envs/sm_ont-process_reads/bin/NanoFilt --length 500 --quality 7 --headcrop 25 --tailcrop 25 {raw_fq} >{sample}.filtered.fastq

# %%
# !conda run -n n50 --cwd . --live-stream n50 --format csv $(ls *.filtered.fastq) >n50_filtered_reads.csv

# %%
n50_df = pd.read_csv("n50_filtered_reads.csv", sep=",")
n50_df
# Out:
#                         #path     seqs         size    N50  min     max   N75  \
# 0        smbre.filtered.fastq  2156891  13733527914  16145  500  193069  7657
# 1         smeg.filtered.fastq  2096508  12631573135  12491  500  236942  5659
# 2  smle_pzq_er.filtered.fastq  1330051   7000372416  12071  500  447354  4953
# 3         smor.filtered.fastq  3413369  14119478724   8668  500  168273  3430
# 4  smle_pzq_es.filtered.fastq  3662716  23840253863  13824  500  202196  5893
#
#     N90        auN
# 0  2728  357349.74
# 1  2587  399825.88
# 2  2105  227185.13
# 3  1618  598308.11
# 4  2659  624239.05

# %%
Path("{}/results/minimap2".format(proj_dir)).mkdir(parents=True, exist_ok=True)
os.chdir("{}/results/minimap2".format(proj_dir))

# %%
# for sample in samples:
for sample in ["smle_pzq_es"]:
    sam      = "{}/results/minimap2/{}.sam".format(proj_dir, sample)
    query_fq = "{}/results/nanofilt/{}.filtered.fastq".format(proj_dir, sample)

    print("###################### {} ##################".format(sample))
    !~/anaconda3/envs/sm_ont-process_reads/bin/minimap2 -a -o {sam} -t 48 -x map-ont {ref_fas} {query_fq}
# Out:
# ###################### smle_pzq_es ##################
# [M::mm_idx_gen::11.489*1.68] collected minimizers
# [M::mm_idx_gen::13.279*2.42] sorted minimizers
# [M::main::13.279*2.42] loaded/built the index for 12 target sequence(s)
# [M::mm_mapopt_update::14.118*2.34] mid_occ = 416
# [M::mm_idx_stat] kmer size: 15; skip: 10; is_hpc: 0; #seq: 12
# [M::mm_idx_stat::14.681*2.28] distinct minimizers: 30119087 (65.35% are singletons); average occurrences: 2.439; average spacing: 5.327; total length: 391422238
# [M::worker_pipeline::214.298*29.98] mapped 42338 sequences
# [M::worker_pipeline::390.138*31.90] mapped 40808 sequences
# [M::worker_pipeline::588.947*32.25] mapped 43306 sequences
# [M::worker_pipeline::830.022*32.30] mapped 45455 sequences
# [M::worker_pipeline::1051.682*32.12] mapped 44703 sequences
# [M::worker_pipeline::1289.362*31.59] mapped 45693 sequences
# [M::worker_pipeline::1470.012*32.22] mapped 47806 sequences
# [M::worker_pipeline::1696.452*32.12] mapped 45932 sequences
# [M::worker_pipeline::1916.264*31.95] mapped 47284 sequences
# [M::worker_pipeline::2103.592*32.13] mapped 48028 sequences
# [M::worker_pipeline::2304.990*32.24] mapped 49325 sequences
# [M::worker_pipeline::2494.646*32.47] mapped 50218 sequences
# [M::worker_pipeline::2717.671*32.28] mapped 49571 sequences
# [M::worker_pipeline::2898.281*32.52] mapped 49790 sequences
# [M::worker_pipeline::3096.096*32.53] mapped 51413 sequences
# [M::worker_pipeline::3288.826*32.55] mapped 53354 sequences
# [M::worker_pipeline::3537.461*32.11] mapped 53951 sequences
# [M::worker_pipeline::3732.637*32.17] mapped 53719 sequences
# [M::worker_pipeline::3940.025*32.09] mapped 56807 sequences
# [M::worker_pipeline::4112.592*32.21] mapped 55685 sequences
# [M::worker_pipeline::4310.755*32.19] mapped 59269 sequences
# [M::worker_pipeline::4539.062*32.29] mapped 48605 sequences
# [M::worker_pipeline::4782.077*32.26] mapped 45151 sequences
# [M::worker_pipeline::4994.360*32.35] mapped 43831 sequences
# [M::worker_pipeline::5221.479*32.45] mapped 44343 sequences
# [M::worker_pipeline::5444.817*32.50] mapped 44640 sequences
# [M::worker_pipeline::5684.431*32.44] mapped 45538 sequences
# [M::worker_pipeline::5866.860*32.59] mapped 134943 sequences
# [M::worker_pipeline::6041.373*32.73] mapped 133880 sequences
# [M::worker_pipeline::6222.160*32.86] mapped 133272 sequences
# [M::worker_pipeline::6419.560*32.90] mapped 132816 sequences
# [M::worker_pipeline::6601.796*33.00] mapped 131336 sequences
# [M::worker_pipeline::6793.441*33.04] mapped 130610 sequences
# [M::worker_pipeline::6972.643*33.17] mapped 127668 sequences
# [M::worker_pipeline::7149.058*33.29] mapped 127555 sequences
# [M::worker_pipeline::7314.339*33.38] mapped 141249 sequences
# [M::worker_pipeline::7499.906*33.46] mapped 118698 sequences
# [M::worker_pipeline::7698.053*33.54] mapped 95874 sequences
# [M::worker_pipeline::7900.189*33.61] mapped 95068 sequences
# [M::worker_pipeline::8098.936*33.70] mapped 95263 sequences
# [M::worker_pipeline::8289.017*33.81] mapped 95789 sequences
# [M::worker_pipeline::8475.551*33.92] mapped 97350 sequences
# [M::worker_pipeline::8688.873*33.92] mapped 97320 sequences
# [M::worker_pipeline::8884.251*34.00] mapped 99976 sequences
# [M::worker_pipeline::9054.041*34.08] mapped 100132 sequences
# [M::worker_pipeline::9228.106*34.16] mapped 100400 sequences
# [M::worker_pipeline::9421.437*34.20] mapped 99759 sequences
# [M::worker_pipeline::9539.774*34.24] mapped 67195 sequences
# [M::main] Version: 2.24-r1122
# [M::main] CMD: /master/nplatt/anaconda3/envs/sm_ont-process_reads/bin/minimap2 -a -o /master/nplatt/sm_nanopore/results/minimap2/smle_pzq_es.sam -t 48 -x map-ont /master/nplatt/sm_nanopore/data/genome/GCA_000237925.5.fa /master/nplatt/sm_nanopore/results/nanofilt/smle_pzq_es.filtered.fastq
# [M::main] Real time: 9540.184 sec; CPU: 326642.700 sec; Peak RSS: 26.741 GB

# %%
# for sample in samples:
for sample in ["smle_pzq_es"]:
    sam      = "{}/results/minimap2/{}.sam".format(proj_dir, sample)
    query_fq = "{}/results/nanofilt/{}.filtered.fastq".format(proj_dir, sample)
    
    print("###################### {} ##################".format(sample))

    #sort bam
    print("...sort...")
    ! ~/anaconda3/envs/sm_ont-process_reads/bin/samtools sort -O bam -o {sample}.bam {sample}.sam
    
    #index bam
    print("...index...")
    ! ~/anaconda3/envs/sm_ont-process_reads/bin/samtools index {sample}.bam
    
    #calculate coverage
    print("...coverage...")
    ! ~/anaconda3/envs/sm_ont-process_reads/bin/mosdepth --threads 4 {sample} {sample}.bam
# Out:
# ###################### smle_pzq_es ##################
# ...sort...
# [bam_sort_core] merging from 60 files and 1 in-memory blocks...
# ...index...
# ...coverage...

# %%
#calculate coverage for a table
# !echo "sample,length,bases,mean,min,max">covs.csv
# !grep "total" *mosdepth.summary.txt | sed 's/:/\t/' | sed 's/\t/,/g' | cut -f1,3-7 -d"," | sed 's/.mosdepth.summary.txt//' >>covs.csv

cov_df=pd.read_csv("covs.csv", sep=",")
cov_df
# Out:
#         sample     length        bases   mean  min    max
# 0        smbre  391422238  12929849971  33.03    0  50586
# 1         smeg  391422238   8667326476  22.14    0  34407
# 2  smle_pzq_er  391422238   6624879196  16.93    0  10350
# 3  smle_pzq_es  391422238  21017040798  53.69    0  43602
# 4         smor  391422238  12178154968  31.11    0  80622

# %%
#play around with igv

# %% [markdown]
# ## Identify structural variants

# %%
Path("{}/results/cutesv".format(proj_dir)).mkdir(parents=True, exist_ok=True)
os.chdir("{}/results/cutesv".format(proj_dir))

# %%
#sv call
# for sample in samples:
for sample in ["smle_pzq_es"]:

    print("###################### {} ##################".format(sample))

    bam      = "{}/results/minimap2/{}.bam".format(proj_dir, sample)
    query_fq = "{}/results/nanofilt/{}.filtered.fastq.gz".format(proj_dir, sample)
    out_dir  = "{}/{}".format(os.getcwd(), sample)
    
    Path("{}".format(out_dir)).mkdir(parents=True, exist_ok=True)
    !~/anaconda3/envs/cutesv/bin/cuteSV --max_cluster_bias_INS 100 --diff_ratio_merging_INS 0.3 --max_cluster_bias_DEL 100 --diff_ratio_merging_DEL 0.3 --threads 12 --min_support 10 --genotype {bam} {ref_fas} {sample}.cutesv.vcf {out_dir}
# Out:
# ###################### smle_pzq_es ##################
# 2023-01-18 11:31:03,178 [INFO] Running /master/nplatt/anaconda3/envs/cutesv/bin/cuteSV --max_cluster_bias_INS 100 --diff_ratio_merging_INS 0.3 --max_cluster_bias_DEL 100 --diff_ratio_merging_DEL 0.3 --threads 12 --min_support 10 --genotype /master/nplatt/sm_nanopore/results/minimap2/smle_pzq_es.bam /master/nplatt/sm_nanopore/data/genome/GCA_000237925.5.fa smle_pzq_es.cutesv.vcf /master/nplatt/sm_nanopore/results/smle_pzq_es
# 2023-01-18 11:31:10,070 [INFO] The total number of chromsomes: 12
# 2023-01-18 11:31:38,245 [INFO] Finished OU426849.1:10000000-10680109.
# 2023-01-18 11:33:46,325 [INFO] Finished HE601624.3:80000000-87984036.
# 2023-01-18 11:34:13,522 [INFO] Finished HE601624.3:30000000-40000000.
# 2023-01-18 11:34:14,461 [INFO] Finished HE601624.3:60000000-70000000.
# 2023-01-18 11:34:14,861 [INFO] Finished HE601624.3:50000000-60000000.
# 2023-01-18 11:34:15,292 [INFO] Finished HE601624.3:40000000-50000000.
# 2023-01-18 11:34:15,396 [INFO] Finished HE601624.3:20000000-30000000.
# 2023-01-18 11:34:16,824 [INFO] Finished HE601624.3:10000000-20000000.
# 2023-01-18 11:34:17,049 [INFO] Finished HE601624.3:70000000-80000000.
# 2023-01-18 11:34:17,800 [INFO] Finished OU426849.1:0-10000000.
# 2023-01-18 11:34:19,942 [INFO] Finished HE601625.3:0-10000000.
# 2023-01-18 11:34:34,885 [INFO] Finished HE601625.3:10000000-20000000.
# 2023-01-18 11:35:10,155 [INFO] Finished HE601624.3:0-10000000.
# 2023-01-18 11:36:26,000 [INFO] Finished OU426850.1:40000000-42949100.
# 2023-01-18 11:39:30,490 [INFO] Finished HE601625.3:40000000-45716228.
# 2023-01-18 11:41:25,195 [INFO] Finished HE601625.3:20000000-30000000.
# 2023-01-18 11:41:56,222 [INFO] Finished OU426850.1:0-10000000.
# 2023-01-18 11:42:09,883 [INFO] Finished OU426850.1:20000000-30000000.
# 2023-01-18 11:42:20,785 [INFO] Finished OU426850.1:30000000-40000000.
# 2023-01-18 11:42:31,292 [INFO] Finished OU426850.1:10000000-20000000.
# 2023-01-18 11:42:41,655 [INFO] Finished HE601626.3:20000000-30000000.
# 2023-01-18 11:44:43,023 [INFO] Finished HE601626.3:0-10000000.
# 2023-01-18 11:44:45,384 [INFO] Finished HE601626.3:30000000-40000000.
# 2023-01-18 11:44:49,712 [INFO] Finished HE601626.3:10000000-20000000.
# 2023-01-18 11:46:12,421 [INFO] Finished HE601626.3:40000000-49793703.
# 2023-01-18 11:47:34,679 [INFO] Finished HE601627.3:40000000-46471565.
# 2023-01-18 11:47:50,871 [INFO] Finished HE601625.3:30000000-40000000.
# 2023-01-18 11:48:14,295 [INFO] Finished HE601628.3:20000000-24128855.
# 2023-01-18 11:48:40,115 [INFO] Finished HE601627.3:0-10000000.
# 2023-01-18 11:49:23,561 [INFO] Finished HE601627.3:10000000-20000000.
# 2023-01-18 11:49:32,025 [INFO] Finished HE601627.3:20000000-30000000.
# 2023-01-18 11:50:03,023 [INFO] Finished HE601627.3:30000000-40000000.
# 2023-01-18 11:50:11,537 [INFO] Finished HE601629.3:20000000-24696071.
# 2023-01-18 11:52:31,369 [INFO] Finished HE601628.3:10000000-20000000.
# 2023-01-18 11:52:33,504 [INFO] Finished HE601612.2:0-26917.
# 2023-01-18 11:52:38,871 [INFO] Finished OU426848.1:30000000-33063208.
# 2023-01-18 11:52:53,278 [INFO] Finished HE601628.3:0-10000000.
# 2023-01-18 11:53:11,865 [INFO] Finished HE601629.3:10000000-20000000.
# 2023-01-18 11:53:32,868 [INFO] Finished HE601629.3:0-10000000.
# 2023-01-18 11:53:35,289 [INFO] Finished OU426848.1:0-10000000.
# 2023-01-18 11:53:36,901 [INFO] Finished OU426848.1:10000000-20000000.
# 2023-01-18 11:53:37,627 [INFO] Finished OU426848.1:20000000-30000000.
# 2023-01-18 11:53:43,843 [INFO] Finished HE601630.3:0-10000000.
# 2023-01-18 11:53:51,094 [INFO] Finished HE601630.3:10000000-19942475.
# 2023-01-18 11:54:25,263 [INFO] Finished HE601631.3:0-5969971.
# 2023-01-18 11:54:25,329 [INFO] Rebuilding signatures of structural variants.
# 2023-01-18 11:56:15,987 [INFO] Clustering structural variants.
# 2023-01-18 11:56:17,909 [INFO] Finished HE601612.2:DEL.
# 2023-01-18 11:56:17,962 [INFO] Finished HE601631.3:DEL.
# 2023-01-18 11:56:18,360 [INFO] Finished OU426849.1:DEL.
# 2023-01-18 11:56:18,622 [INFO] Finished OU426848.1:DEL.
# 2023-01-18 11:56:18,799 [INFO] Finished HE601630.3:DEL.
# 2023-01-18 11:56:19,175 [INFO] Finished HE601629.3:DEL.
# 2023-01-18 11:56:19,185 [INFO] Finished HE601628.3:DEL.
# 2023-01-18 11:56:19,819 [INFO] Finished OU426850.1:DEL.
# 2023-01-18 11:56:19,840 [INFO] Finished HE601612.2:INS.
# 2023-01-18 11:56:20,084 [INFO] Finished HE601627.3:DEL.
# 2023-01-18 11:56:20,261 [INFO] Finished HE601625.3:DEL.
# 2023-01-18 11:56:20,445 [INFO] Finished HE601626.3:DEL.
# 2023-01-18 11:56:21,791 [INFO] Finished HE601631.3:INS.
# 2023-01-18 11:56:22,037 [INFO] Finished HE601624.3:DEL.
# 2023-01-18 11:56:22,241 [INFO] Finished HE601628.3:INS.
# 2023-01-18 11:56:22,295 [INFO] Finished HE601629.3:INS.
# 2023-01-18 11:56:22,403 [INFO] Finished HE601625.3:INS.
# 2023-01-18 11:56:22,448 [INFO] Finished HE601630.3:INS.
# 2023-01-18 11:56:22,468 [INFO] Finished OU426849.1:INS.
# 2023-01-18 11:56:22,555 [INFO] Finished OU426848.1:INS.
# 2023-01-18 11:56:22,626 [INFO] Finished HE601627.3:INS.
# 2023-01-18 11:56:22,841 [INFO] Finished HE601626.3:INS.
# 2023-01-18 11:56:23,023 [INFO] Finished HE601612.2:INV.
# 2023-01-18 11:56:23,719 [INFO] Finished HE601624.3:INS.
# 2023-01-18 11:56:23,801 [INFO] Finished HE601631.3:INV.
# 2023-01-18 11:56:24,047 [INFO] Finished OU426850.1:INS.
# 2023-01-18 11:56:24,217 [INFO] Finished HE601630.3:INV.
# 2023-01-18 11:56:24,223 [INFO] Finished HE601628.3:INV.
# 2023-01-18 11:56:24,337 [INFO] Finished HE601629.3:INV.
# 2023-01-18 11:56:24,422 [INFO] Finished OU426849.1:INV.
# 2023-01-18 11:56:24,499 [INFO] Finished OU426848.1:INV.
# 2023-01-18 11:56:24,849 [INFO] Finished HE601625.3:INV.
# 2023-01-18 11:56:24,864 [INFO] Finished HE601627.3:INV.
# 2023-01-18 11:56:25,029 [INFO] Finished HE601626.3:INV.
# 2023-01-18 11:56:25,060 [INFO] Finished HE601612.2:DUP.
# 2023-01-18 11:56:25,831 [INFO] Finished HE601624.3:INV.
# 2023-01-18 11:56:26,023 [INFO] Finished HE601631.3:DUP.
# 2023-01-18 11:56:26,031 [INFO] Finished OU426850.1:INV.
# 2023-01-18 11:56:26,091 [INFO] Finished HE601612.2-HE601624.3:TRA/BND.
# 2023-01-18 11:56:26,098 [INFO] Finished HE601612.2-HE601625.3:TRA/BND.
# 2023-01-18 11:56:26,158 [INFO] Finished HE601612.2-HE601626.3:TRA/BND.
# 2023-01-18 11:56:26,160 [INFO] Finished HE601628.3:DUP.
# 2023-01-18 11:56:26,164 [INFO] Finished HE601612.2-HE601627.3:TRA/BND.
# 2023-01-18 11:56:26,224 [INFO] Finished HE601612.2-HE601628.3:TRA/BND.
# 2023-01-18 11:56:26,226 [INFO] Finished HE601612.2-HE601629.3:TRA/BND.
# 2023-01-18 11:56:26,230 [INFO] Finished HE601612.2-HE601630.3:TRA/BND.
# 2023-01-18 11:56:26,290 [INFO] Finished HE601612.2-HE601631.3:TRA/BND.
# 2023-01-18 11:56:26,291 [INFO] Finished HE601612.2-OU426848.1:TRA/BND.
# 2023-01-18 11:56:26,297 [INFO] Finished HE601612.2-OU426849.1:TRA/BND.
# 2023-01-18 11:56:26,335 [INFO] Finished HE601629.3:DUP.
# 2023-01-18 11:56:26,356 [INFO] Finished HE601612.2-OU426850.1:TRA/BND.
# 2023-01-18 11:56:26,436 [INFO] Finished OU426849.1:DUP.
# 2023-01-18 11:56:26,479 [INFO] Finished HE601630.3:DUP.
# 2023-01-18 11:56:26,638 [INFO] Finished HE601625.3:DUP.
# 2023-01-18 11:56:26,668 [INFO] Finished OU426848.1:DUP.
# 2023-01-18 11:56:26,695 [INFO] Finished HE601627.3:DUP.
# 2023-01-18 11:56:26,747 [INFO] Finished HE601624.3-HE601629.3:TRA/BND.
# 2023-01-18 11:56:26,818 [INFO] Finished HE601626.3:DUP.
# 2023-01-18 11:56:26,852 [INFO] Finished HE601624.3-HE601631.3:TRA/BND.
# 2023-01-18 11:56:26,899 [INFO] Finished HE601624.3-HE601628.3:TRA/BND.
# 2023-01-18 11:56:26,960 [INFO] Finished HE601624.3-HE601627.3:TRA/BND.
# 2023-01-18 11:56:26,976 [INFO] Finished HE601624.3-OU426848.1:TRA/BND.
# 2023-01-18 11:56:27,004 [INFO] Finished HE601625.3-HE601627.3:TRA/BND.
# 2023-01-18 11:56:27,018 [INFO] Finished HE601624.3-OU426849.1:TRA/BND.
# 2023-01-18 11:56:27,073 [INFO] Finished HE601624.3-HE601625.3:TRA/BND.
# 2023-01-18 11:56:27,094 [INFO] Finished HE601625.3-HE601630.3:TRA/BND.
# 2023-01-18 11:56:27,119 [INFO] Finished HE601624.3-HE601630.3:TRA/BND.
# 2023-01-18 11:56:27,123 [INFO] Finished HE601625.3-OU426848.1:TRA/BND.
# 2023-01-18 11:56:27,146 [INFO] Finished HE601625.3-HE601628.3:TRA/BND.
# 2023-01-18 11:56:27,152 [INFO] Finished HE601625.3-HE601631.3:TRA/BND.
# 2023-01-18 11:56:27,220 [INFO] Finished HE601624.3-HE601626.3:TRA/BND.
# 2023-01-18 11:56:27,233 [INFO] Finished HE601625.3-HE601626.3:TRA/BND.
# 2023-01-18 11:56:27,294 [INFO] Finished HE601625.3-OU426849.1:TRA/BND.
# 2023-01-18 11:56:27,314 [INFO] Finished HE601626.3-HE601630.3:TRA/BND.
# 2023-01-18 11:56:27,360 [INFO] Finished HE601626.3-HE601627.3:TRA/BND.
# 2023-01-18 11:56:27,385 [INFO] Finished HE601626.3-HE601628.3:TRA/BND.
# 2023-01-18 11:56:27,385 [INFO] Finished HE601625.3-OU426850.1:TRA/BND.
# 2023-01-18 11:56:27,399 [INFO] Finished HE601625.3-HE601629.3:TRA/BND.
# 2023-01-18 11:56:27,427 [INFO] Finished HE601626.3-HE601629.3:TRA/BND.
# 2023-01-18 11:56:27,431 [INFO] Finished HE601626.3-OU426848.1:TRA/BND.
# 2023-01-18 11:56:27,469 [INFO] Finished HE601626.3-OU426849.1:TRA/BND.
# 2023-01-18 11:56:27,489 [INFO] Finished HE601624.3-OU426850.1:TRA/BND.
# 2023-01-18 11:56:27,576 [INFO] Finished HE601627.3-OU426848.1:TRA/BND.
# 2023-01-18 11:56:27,582 [INFO] Finished HE601627.3-HE601631.3:TRA/BND.
# 2023-01-18 11:56:27,590 [INFO] Finished HE601627.3-HE601629.3:TRA/BND.
# 2023-01-18 11:56:27,658 [INFO] Finished HE601627.3-HE601628.3:TRA/BND.
# 2023-01-18 11:56:27,709 [INFO] Finished HE601626.3-HE601631.3:TRA/BND.
# 2023-01-18 11:56:27,712 [INFO] Finished HE601624.3:DUP.
# 2023-01-18 11:56:27,727 [INFO] Finished HE601628.3-OU426848.1:TRA/BND.
# 2023-01-18 11:56:27,737 [INFO] Finished HE601628.3-HE601630.3:TRA/BND.
# 2023-01-18 11:56:27,744 [INFO] Finished HE601627.3-OU426849.1:TRA/BND.
# 2023-01-18 11:56:27,755 [INFO] Finished HE601628.3-HE601631.3:TRA/BND.
# 2023-01-18 11:56:27,766 [INFO] Finished HE601628.3-OU426849.1:TRA/BND.
# 2023-01-18 11:56:27,782 [INFO] Finished HE601627.3-OU426850.1:TRA/BND.
# 2023-01-18 11:56:27,792 [INFO] Finished HE601629.3-HE601631.3:TRA/BND.
# 2023-01-18 11:56:27,799 [INFO] Finished HE601628.3-HE601629.3:TRA/BND.
# 2023-01-18 11:56:27,806 [INFO] Finished HE601626.3-OU426850.1:TRA/BND.
# 2023-01-18 11:56:27,819 [INFO] Finished HE601627.3-HE601630.3:TRA/BND.
# 2023-01-18 11:56:27,832 [INFO] Finished HE601630.3-HE601631.3:TRA/BND.
# 2023-01-18 11:56:27,847 [INFO] Finished HE601630.3-OU426848.1:TRA/BND.
# 2023-01-18 11:56:27,856 [INFO] Finished HE601630.3-OU426849.1:TRA/BND.
# 2023-01-18 11:56:27,860 [INFO] Finished HE601629.3-OU426849.1:TRA/BND.
# 2023-01-18 11:56:27,864 [INFO] Finished HE601630.3-OU426850.1:TRA/BND.
# 2023-01-18 11:56:27,874 [INFO] Finished HE601631.3-OU426848.1:TRA/BND.
# 2023-01-18 11:56:27,896 [INFO] Finished HE601629.3-OU426850.1:TRA/BND.
# 2023-01-18 11:56:27,918 [INFO] Finished HE601631.3-OU426849.1:TRA/BND.
# 2023-01-18 11:56:27,931 [INFO] Finished HE601629.3-HE601630.3:TRA/BND.
# 2023-01-18 11:56:27,949 [INFO] Finished OU426848.1-OU426849.1:TRA/BND.
# 2023-01-18 11:56:27,949 [INFO] Finished HE601629.3-OU426848.1:TRA/BND.
# 2023-01-18 11:56:27,950 [INFO] Finished OU426849.1-OU426850.1:TRA/BND.
# 2023-01-18 11:56:27,977 [INFO] Finished HE601631.3-OU426850.1:TRA/BND.
# 2023-01-18 11:56:28,066 [INFO] Finished OU426848.1-OU426850.1:TRA/BND.
# 2023-01-18 11:56:28,132 [INFO] Finished OU426850.1:DUP.
# 2023-01-18 11:56:28,176 [INFO] Finished HE601628.3-OU426850.1:TRA/BND.
# 2023-01-18 11:56:28,282 [INFO] Writing to your output file.
# 2023-01-18 11:56:28,304 [INFO] Loading reference genome...
# 2023-01-18 11:56:51,966 [INFO] Cleaning temporary files.
# 2023-01-18 11:56:52,691 [INFO] Finished in 1549.51 seconds.

# %% [markdown]
# ## Read Correction

# %%
Path("{}/results/read_correction".format(proj_dir)).mkdir(parents=True, exist_ok=True)
os.chdir("{}/results/read_correction".format(proj_dir))

for sample in samples:
    print("###################### {} ##################".format(sample))
    Path("{}/results/read_correction/{}".format(proj_dir, sample)).mkdir(parents=True, exist_ok=True)
    
    os.chdir("{}/results/read_correction".format(proj_dir, sample))
    
    # !conda run -n ont_assembly --cwd . --live-stream canu -correct -genomesize=385m -useGrid=False -p {sample}  -nanopore {proj_dir}/results/raw_reads/{sample}.raw_pass.fastq
    
    os.chdir("{}/results/read_correction".format(proj_dir))

# %%
# %%bash

for SAMPLE in 'smor' 'smle_pzq_es' 'smle_pzq_er' 'smbre' 'smeg'; do

    if [ -d ${SAMPLE} ]; then
        rm -rf ${SAMPLE}
    fi
    
    mkdir ${SAMPLE}
    cd ${SAMPLE}
    
    LOG=$(pwd)/${SAMPLE}.log 
    
    QSUB="qsub -V -cwd -S /bin/bash -q all.q -j y -pe smp 192 -N ${SAMPLE} -o ${LOG}"
    CMD="conda run -n ont_assembly --cwd . --live-stream canu -correct -genomesize=385m -useGrid=False -p ${SAMPLE}  -nanopore /master/nplatt/sm_nanopore/results/raw_reads/${SAMPLE}.raw_pass.fastq"
    
    echo $CMD | $QSUB
    cd ..
done

for SAMPLE in 'smor' 'smle_pzq_es' 'smbre'; do
    rm -rf $SAMPLE*
    QSUB="qsub -V -cwd -S /bin/bash -q all.q -j y -pe smp 192 -N ${SAMPLE} -o ${SAMPLE}.log"
    CMD="conda run -n ont_assembly --cwd . --live-stream canu -correct -genomesize=385m -useGrid=False -p ${SAMPLE}/${SAMPLE}  -nanopore /master/nplatt/sm_nanopore/results/raw_reads/${SAMPLE}.raw_pass.fastq"
    
    echo $CMD | $QSUB
done

# %% [markdown]
# ## Genome assembly

# %%
Path("{}/results/assembly".format(proj_dir)).mkdir(parents=True, exist_ok=True)
os.chdir("{}/results/assembly".format(proj_dir))

# %%
for sample in samples:
    print("###################### {} ##################".format(sample))
    # !flye --nano-cor {proj_dir}/results/read_correction/{sample}.correctedReads.fasta.gz -g 385m -t 128 -i 3 -o {sample}_rnd0

# %%
for SAMPLE in 'smor' 'smle_pzq_es' 'smle_pzq_er' 'smbre' 'smeg'; do

    if [ -d ${SAMPLE} ]; then
        rm -rf ${SAMPLE}
    fi
    
    mkdir ${SAMPLE}
    cd ${SAMPLE}
    
    LOG=$(pwd)/${SAMPLE}.log 
    READS="/master/nplatt/sm_nanopore/results/read_correction/${SAMPLE}/${SAMPLE}.correctedReads.fasta.gz"
    OUT="/master/nplatt/sm_nanopore/results/assembly/${SAMPLE}/${SAMPLE}_rnd0"
    
    QSUB="qsub -V -cwd -S /bin/bash -q all.q -j y -pe smp 128 -N ${SAMPLE} -o ${LOG}"
    CMD="conda run -n sm_ont-process_reads --cwd . --live-stream flye --nano-cor ${READS} -g 385m -t 128 -i 3 -o ${OUT}"
    
    echo $CMD | $QSUB
    cd ..
done

# %%
#get df of assembly stats
total_lengths=[]
fragments=[]
fragment_n50s=[]
largest_frags=[]
scaffolds=[]
mean_coverages=[]
    
for sample in samples:
    info = !tail -n 8 {sample}/{sample}.log | head -n 6
    total_lengths.append(info[0].split("\t")[-1])
    fragments.append(info[1].split("\t")[-1])
    fragment_n50s.append(info[2].split("\t")[-1])
    largest_frags.append(info[3].split("\t")[-1])
    scaffolds.append(info[4].split("\t")[-1])
    mean_coverages.append(info[5].split("\t")[-1])
    
assembly_df=pd.DataFrame(data = [samples, total_lengths, fragments, fragment_n50s, largest_frags, scaffolds, mean_coverages]).T
assembly_df.columns=["sample", "total_length", "fragments", "fragment_n50", "largest_fragment", "scaffolds", "mean_coverage"]
assembly_df.to_csv("assembly_info.csv", index=False)
assembly_df
# Out:
#         sample total_length fragments fragment_n50 largest_fragment scaffolds  \
# 0         smor    386656054      1674      2150179          8090473         0
# 1  smle_pzq_es    403425661      1122      3481572         14813648         0
# 2  smle_pzq_er    382213358      1968      1273691          5768858         0
# 3        smbre    384951218      1020      2298594         14522024         0
# 4         smeg    370379461      1963       871323          6130221         0
#
#   mean_coverage
# 0            23
# 1            33
# 2            15
# 3            24
# 4            14

# %%
for sample in samples:
    print(sample)
    ! cp /master/nplatt/sm_nanopore/results/assembly/{sample}/{sample}_rnd0/assembly.fasta {sample}_rnd0.fasta
# Out:
# smor
# smle_pzq_es
# smle_pzq_er
# smbre
# smeg

# %% [markdown]
# ## polish assembly

# %%
Path("{}/results/polish_assembly".format(proj_dir)).mkdir(parents=True, exist_ok=True)
os.chdir("{}/results/polish_assembly".format(proj_dir))

# %%
for sample in samples:
    print(sample)
    # !ln -s /master/nplatt/sm_nanopore/results/assembly/{sample}_rnd0.fasta {sample}.assembly_rnd0.fasta
# Out:
# smor
# smle_pzq_es
# smle_pzq_er
# smbre
# smeg

# %%
#set the initial round
rnd=1
for sample in samples:
    print("###################### {} ##################".format(sample))

    for rnd in [1, 2, 3]:
        #define major i/o files
        current_assembly = "{}.assembly_rnd{}.fasta".format(sample, str(rnd-1))
        corrected_reads = "{}/results/read_correction/{}/{}.correctedReads.fasta.gz".format(proj_dir, sample, sample)
        polished_assembly = "{}.assembly_rnd{}.fasta".format(sample, str(rnd))
        n_threads=48
        
        #map corrected reads to the assembly
        print("R{}: map".format(rnd))
        minimap_cmd = "conda run -n sm_ont-process_reads --cwd . --live-stream \
            minimap2 \
                -a \
                -map-ont \
                -t {} \
                {} \
                {}  \
                >{}.racon_rnd{}.sam".format(n_threads, current_assembly, corrected_reads, sample, rnd)
        minimap_cmd=' '.join(minimap_cmd.split())
        ! {minimap_cmd}

        #polish the assembly
        print("R{}: polish".format(rnd))
        racon_cmd = "conda run -n sm_ont-process_reads --cwd . --live-stream \
            racon \
                -t {} \
                {} \
                {}.racon_rnd{}.sam \
                {} \
                >{}".format(n_threads, corrected_reads, sample, rnd, current_assembly, polished_assembly)
        racon_cmd=' '.join(racon_cmd.split())
        ! {racon_cmd}
        print("#")
# Out:
# ###################### smor ##################
# R1: map
# [M::mm_idx_gen::7.984*1.68] collected minimizers
# [M::mm_idx_gen::9.287*2.93] sorted minimizers
# [M::main::9.288*2.93] loaded/built the index for 1674 target sequence(s)
# [M::mm_mapopt_update::10.191*2.76] mid_occ = 384
# [M::mm_idx_stat] kmer size: 15; skip: 10; is_hpc: 0; #seq: 1674
# [M::mm_idx_stat::10.857*2.65] distinct minimizers: 30374815 (65.19% are singletons); average occurrences: 2.391; average spacing: 5.323; total length: 386656054
# [M::worker_pipeline::152.226*39.59] mapped 79894 sequences
# [M::worker_pipeline::307.705*40.33] mapped 77039 sequences
# [M::worker_pipeline::476.213*40.86] mapped 74651 sequences
# [M::worker_pipeline::629.258*41.74] mapped 76580 sequences
# [M::worker_pipeline::794.384*41.56] mapped 73726 sequences
# [M::worker_pipeline::965.772*41.19] mapped 76750 sequences
# [M::worker_pipeline::1144.195*40.83] mapped 76077 sequences
# [M::worker_pipeline::1289.656*41.18] mapped 77343 sequences
# [M::worker_pipeline::1453.221*41.22] mapped 75661 sequences
# [M::worker_pipeline::1617.462*40.85] mapped 78790 sequences
# [M::worker_pipeline::1764.942*41.05] mapped 78853 sequences
# [M::worker_pipeline::1933.526*41.06] mapped 76202 sequences
# [M::worker_pipeline::2095.499*41.02] mapped 73981 sequences
# [M::worker_pipeline::2273.516*41.00] mapped 70832 sequences
# [M::worker_pipeline::2436.701*41.12] mapped 70994 sequences
# [M::worker_pipeline::2600.532*41.11] mapped 72574 sequences
# [M::worker_pipeline::2774.577*40.99] mapped 71286 sequences
# [M::worker_pipeline::2945.959*40.93] mapped 72852 sequences
# [M::worker_pipeline::3124.810*40.87] mapped 73865 sequences
# [M::worker_pipeline::3281.401*40.90] mapped 75586 sequences
# [M::worker_pipeline::3432.424*40.51] mapped 60781 sequences
# [M::main] Version: 2.24-r1122
# [M::main] CMD: minimap2 -a -map-ont -t 48 smor.assembly_rnd0.fasta /master/nplatt/sm_nanopore/results/read_correction/smor/smor.correctedReads.fasta.gz
# [M::main] Real time: 3432.825 sec; CPU: 139062.435 sec; Peak RSS: 22.556 GB
# R1: polish
# [racon::Polisher::initialize] loaded target sequences 2.139771 s
# [racon::Polisher::initialize] loaded sequences 101.550652 s
# [racon::Polisher::initialize] loaded overlaps 69.268296 s
# [racon::Polisher::initialize] aligning overlaps [====================] 19.301929 s
# [racon::Polisher::initialize] transformed data into windows 18.209538 s
# [racon::Polisher::polish] generating consensus [====================] 195.514138 s
# [racon::Polisher::] total = 410.996559 s
# #
# R2: map
# [M::mm_idx_gen::7.581*1.74] collected minimizers
# [M::mm_idx_gen::8.810*2.82] sorted minimizers
# [M::main::8.811*2.82] loaded/built the index for 1399 target sequence(s)
# [M::mm_mapopt_update::9.549*2.68] mid_occ = 381
# [M::mm_idx_stat] kmer size: 15; skip: 10; is_hpc: 0; #seq: 1399
# [M::mm_idx_stat::10.053*2.59] distinct minimizers: 30397504 (65.24% are singletons); average occurrences: 2.386; average spacing: 5.322; total length: 385948710
# [M::worker_pipeline::147.574*39.59] mapped 79894 sequences
# [M::worker_pipeline::306.812*39.36] mapped 77039 sequences
# [M::worker_pipeline::475.756*40.33] mapped 74651 sequences
# [M::worker_pipeline::626.544*41.34] mapped 76580 sequences
# [M::worker_pipeline::782.457*41.45] mapped 73726 sequences
# [M::worker_pipeline::953.096*40.96] mapped 76750 sequences
# [M::worker_pipeline::1131.399*40.50] mapped 76077 sequences
# [M::worker_pipeline::1274.639*40.97] mapped 77343 sequences
# [M::worker_pipeline::1429.701*41.17] mapped 75661 sequences
# [M::worker_pipeline::1598.395*40.68] mapped 78790 sequences
# [M::worker_pipeline::1744.064*40.88] mapped 78853 sequences
# [M::worker_pipeline::1908.716*40.89] mapped 76202 sequences
# [M::worker_pipeline::2065.932*40.87] mapped 73981 sequences
# [M::worker_pipeline::2236.008*40.94] mapped 70832 sequences
# [M::worker_pipeline::2390.563*41.10] mapped 70994 sequences
# [M::worker_pipeline::2546.478*41.15] mapped 72574 sequences
# [M::worker_pipeline::2715.094*41.06] mapped 71286 sequences
# [M::worker_pipeline::2882.604*41.01] mapped 72852 sequences
# [M::worker_pipeline::3054.230*40.98] mapped 73865 sequences
# [M::worker_pipeline::3206.423*41.03] mapped 75586 sequences
# [M::worker_pipeline::3349.963*40.66] mapped 60781 sequences
# [M::main] Version: 2.24-r1122
# [M::main] CMD: minimap2 -a -map-ont -t 48 smor.assembly_rnd1.fasta /master/nplatt/sm_nanopore/results/read_correction/smor/smor.correctedReads.fasta.gz
# [M::main] Real time: 3350.317 sec; CPU: 136217.193 sec; Peak RSS: 23.181 GB
# R2: polish
# [racon::Polisher::initialize] loaded target sequences 2.144430 s
# [racon::Polisher::initialize] loaded sequences 102.767956 s
# [racon::Polisher::initialize] loaded overlaps 26.603356 s
# [racon::Polisher::initialize] aligning overlaps [====================] 14.940295 s
# [racon::Polisher::initialize] transformed data into windows 19.916187 s
# [racon::Polisher::polish] generating consensus [====================] 185.418094 s
# [racon::Polisher::] total = 356.933251 s
# #
# R3: map
# [M::mm_idx_gen::7.605*1.71] collected minimizers
# [M::mm_idx_gen::8.852*2.83] sorted minimizers
# [M::main::8.852*2.83] loaded/built the index for 1369 target sequence(s)
# [M::mm_mapopt_update::9.541*2.69] mid_occ = 380
# [M::mm_idx_stat] kmer size: 15; skip: 10; is_hpc: 0; #seq: 1369
# [M::mm_idx_stat::10.048*2.61] distinct minimizers: 30396595 (65.25% are singletons); average occurrences: 2.385; average spacing: 5.322; total length: 385763855
# [M::worker_pipeline::146.197*39.51] mapped 79894 sequences
# [M::worker_pipeline::302.011*39.61] mapped 77039 sequences
# [M::worker_pipeline::468.536*40.38] mapped 74651 sequences
# [M::worker_pipeline::617.183*41.40] mapped 76580 sequences
# [M::worker_pipeline::773.340*41.48] mapped 73726 sequences
# [M::worker_pipeline::942.110*41.02] mapped 76750 sequences
# [M::worker_pipeline::1116.024*40.56] mapped 76077 sequences
# [M::worker_pipeline::1255.488*41.05] mapped 77343 sequences
# [M::worker_pipeline::1407.854*41.27] mapped 75661 sequences
# [M::worker_pipeline::1573.150*40.80] mapped 78790 sequences
# [M::worker_pipeline::1716.360*40.98] mapped 78853 sequences
# [M::worker_pipeline::1882.881*40.93] mapped 76202 sequences
# [M::worker_pipeline::2039.833*40.90] mapped 73981 sequences
# [M::worker_pipeline::2211.866*40.93] mapped 70832 sequences
# [M::worker_pipeline::2363.239*41.12] mapped 70994 sequences
# [M::worker_pipeline::2526.774*41.04] mapped 72574 sequences
# [M::worker_pipeline::2688.484*41.03] mapped 71286 sequences
# [M::worker_pipeline::2854.296*40.93] mapped 72852 sequences
# [M::worker_pipeline::3021.929*40.90] mapped 73865 sequences
# [M::worker_pipeline::3172.232*40.99] mapped 75586 sequences
# [M::worker_pipeline::3315.903*40.62] mapped 60781 sequences
# [M::main] Version: 2.24-r1122
# [M::main] CMD: minimap2 -a -map-ont -t 48 smor.assembly_rnd2.fasta /master/nplatt/sm_nanopore/results/read_correction/smor/smor.correctedReads.fasta.gz
# [M::main] Real time: 3316.345 sec; CPU: 134699.331 sec; Peak RSS: 23.595 GB
# R3: polish
# [racon::Polisher::initialize] loaded target sequences 2.149253 s
# [racon::Polisher::initialize] loaded sequences 101.847246 s
# [racon::Polisher::initialize] loaded overlaps 30.492327 s
# [racon::Polisher::initialize] aligning overlaps [====================] 17.914960 s
# [racon::Polisher::initialize] transformed data into windows 19.132240 s
# [racon::Polisher::polish] generating consensus [====================] 188.459564 s
# [racon::Polisher::] total = 364.686051 s
# #
# ###################### smle_pzq_es ##################
# R1: map
# [M::mm_idx_gen::7.896*1.71] collected minimizers
# [M::mm_idx_gen::9.202*2.90] sorted minimizers
# [M::main::9.202*2.90] loaded/built the index for 1122 target sequence(s)
# [M::mm_mapopt_update::9.895*2.77] mid_occ = 407
# [M::mm_idx_stat] kmer size: 15; skip: 10; is_hpc: 0; #seq: 1122
# [M::mm_idx_stat::10.381*2.69] distinct minimizers: 30553214 (64.52% are singletons); average occurrences: 2.479; average spacing: 5.325; total length: 403425661
# [M::worker_pipeline::172.686*39.54] mapped 19853 sequences
# [M::worker_pipeline::386.693*37.10] mapped 19771 sequences
# [M::worker_pipeline::603.000*37.46] mapped 20643 sequences
# [M::worker_pipeline::811.530*37.68] mapped 20836 sequences
# [M::worker_pipeline::1011.733*37.64] mapped 21265 sequences
# [M::worker_pipeline::1197.420*38.36] mapped 21689 sequences
# [M::worker_pipeline::1399.452*38.45] mapped 21616 sequences
# [M::worker_pipeline::1618.992*37.78] mapped 21757 sequences
# [M::worker_pipeline::1838.404*37.67] mapped 22496 sequences
# [M::worker_pipeline::2029.941*37.99] mapped 22806 sequences
# [M::worker_pipeline::2225.667*38.09] mapped 22165 sequences
# [M::worker_pipeline::2440.700*37.72] mapped 22957 sequences
# [M::worker_pipeline::2630.425*37.87] mapped 23544 sequences
# [M::worker_pipeline::2796.484*38.21] mapped 23371 sequences
# [M::worker_pipeline::2984.129*38.37] mapped 24068 sequences
# [M::worker_pipeline::3170.378*38.56] mapped 24289 sequences
# [M::worker_pipeline::3426.888*38.10] mapped 19452 sequences
# [M::worker_pipeline::3632.253*38.14] mapped 20038 sequences
# [M::worker_pipeline::3866.863*38.10] mapped 20058 sequences
# [M::worker_pipeline::4075.356*38.07] mapped 20416 sequences
# [M::worker_pipeline::4231.939*38.23] mapped 34327 sequences
# [M::worker_pipeline::4367.387*38.40] mapped 41954 sequences
# [M::worker_pipeline::4494.029*38.60] mapped 41664 sequences
# [M::worker_pipeline::4626.822*38.78] mapped 41677 sequences
# [M::worker_pipeline::4780.803*38.85] mapped 41139 sequences
# [M::worker_pipeline::4940.716*39.09] mapped 38763 sequences
# [M::worker_pipeline::5111.640*39.18] mapped 39457 sequences
# [M::worker_pipeline::5289.543*39.24] mapped 39956 sequences
# [M::worker_pipeline::5445.584*39.43] mapped 40366 sequences
# [M::worker_pipeline::5601.922*39.59] mapped 38901 sequences
# [M::worker_pipeline::5639.609*39.60] mapped 8242 sequences
# [M::main] Version: 2.24-r1122
# [M::main] CMD: minimap2 -a -map-ont -t 48 smle_pzq_es.assembly_rnd0.fasta /master/nplatt/sm_nanopore/results/read_correction/smle_pzq_es/smle_pzq_es.correctedReads.fasta.gz
# [M::main] Real time: 5640.001 sec; CPU: 223305.887 sec; Peak RSS: 23.044 GB
# R1: polish
# [racon::Polisher::initialize] loaded target sequences 2.158625 s
# [racon::Polisher::initialize] loaded sequences 146.908151 s
# [racon::Polisher::initialize] loaded overlaps 42.327313 s
# [racon::Polisher::initialize] aligning overlaps [====================] 15.036950 s
# [racon::Polisher::initialize] transformed data into windows 21.089318 s
# [racon::Polisher::polish] generating consensus [====================] 254.333967 s
# [racon::Polisher::] total = 484.502313 s
# #
# R2: map
# [M::mm_idx_gen::8.046*1.69] collected minimizers
# [M::mm_idx_gen::9.265*2.75] sorted minimizers
# [M::main::9.265*2.75] loaded/built the index for 841 target sequence(s)
# [M::mm_mapopt_update::9.942*2.63] mid_occ = 407
# [M::mm_idx_stat] kmer size: 15; skip: 10; is_hpc: 0; #seq: 841
# [M::mm_idx_stat::10.428*2.56] distinct minimizers: 30580531 (64.58% are singletons); average occurrences: 2.471; average spacing: 5.324; total length: 402322301
# [M::worker_pipeline::168.352*40.18] mapped 19853 sequences
# [M::worker_pipeline::373.321*37.82] mapped 19771 sequences
# [M::worker_pipeline::590.770*37.80] mapped 20643 sequences
# [M::worker_pipeline::783.351*38.57] mapped 20836 sequences
# [M::worker_pipeline::983.700*38.27] mapped 21265 sequences
# [M::worker_pipeline::1170.170*38.76] mapped 21689 sequences
# [M::worker_pipeline::1364.587*38.98] mapped 21616 sequences
# [M::worker_pipeline::1580.043*38.22] mapped 21757 sequences
# [M::worker_pipeline::1793.657*38.14] mapped 22496 sequences
# [M::worker_pipeline::1985.303*38.38] mapped 22806 sequences
# [M::worker_pipeline::2168.712*38.64] mapped 22165 sequences
# [M::worker_pipeline::2383.598*38.23] mapped 22957 sequences
# [M::worker_pipeline::2569.444*38.34] mapped 23544 sequences
# [M::worker_pipeline::2729.772*38.70] mapped 23371 sequences
# [M::worker_pipeline::2910.914*38.89] mapped 24068 sequences
# [M::worker_pipeline::3096.942*39.04] mapped 24289 sequences
# [M::worker_pipeline::3352.871*38.55] mapped 19452 sequences
# [M::worker_pipeline::3553.176*38.58] mapped 20038 sequences
# [M::worker_pipeline::3786.482*38.50] mapped 20058 sequences
# [M::worker_pipeline::3987.821*38.53] mapped 20416 sequences
# [M::worker_pipeline::4133.279*38.73] mapped 34327 sequences
# [M::worker_pipeline::4264.550*38.92] mapped 41954 sequences
# [M::worker_pipeline::4391.924*39.11] mapped 41664 sequences
# [M::worker_pipeline::4523.552*39.28] mapped 41677 sequences
# [M::worker_pipeline::4675.127*39.36] mapped 41139 sequences
# [M::worker_pipeline::4834.138*39.59] mapped 38763 sequences
# [M::worker_pipeline::5000.242*39.70] mapped 39457 sequences
# [M::worker_pipeline::5174.190*39.76] mapped 39956 sequences
# [M::worker_pipeline::5327.673*39.93] mapped 40366 sequences
# [M::worker_pipeline::5480.221*40.07] mapped 38901 sequences
# [M::worker_pipeline::5517.473*40.07] mapped 8242 sequences
# [M::main] Version: 2.24-r1122
# [M::main] CMD: minimap2 -a -map-ont -t 48 smle_pzq_es.assembly_rnd1.fasta /master/nplatt/sm_nanopore/results/read_correction/smle_pzq_es/smle_pzq_es.correctedReads.fasta.gz
# [M::main] Real time: 5517.820 sec; CPU: 221092.124 sec; Peak RSS: 22.918 GB
# R2: polish
# [racon::Polisher::initialize] loaded target sequences 2.256752 s
# [racon::Polisher::initialize] loaded sequences 147.591536 s
# [racon::Polisher::initialize] loaded overlaps 40.335285 s
# [racon::Polisher::initialize] aligning overlaps [====================] 17.719516 s
# [racon::Polisher::initialize] transformed data into windows 20.023588 s
# [racon::Polisher::polish] generating consensus [====================] 253.454532 s
# [racon::Polisher::] total = 484.181523 s
# #
# R3: map
# [M::mm_idx_gen::9.634*1.66] collected minimizers
# [M::mm_idx_gen::10.842*2.57] sorted minimizers
# [M::main::10.842*2.57] loaded/built the index for 789 target sequence(s)
# [M::mm_mapopt_update::11.581*2.47] mid_occ = 407
# [M::mm_idx_stat] kmer size: 15; skip: 10; is_hpc: 0; #seq: 789
# [M::mm_idx_stat::12.072*2.41] distinct minimizers: 30573180 (64.62% are singletons); average occurrences: 2.470; average spacing: 5.324; total length: 401969069
# [M::worker_pipeline::171.402*39.34] mapped 19853 sequences
# [M::worker_pipeline::380.799*36.89] mapped 19771 sequences
# [M::worker_pipeline::594.338*37.59] mapped 20643 sequences
# [M::worker_pipeline::783.218*38.59] mapped 20836 sequences
# [M::worker_pipeline::978.978*38.38] mapped 21265 sequences
# [M::worker_pipeline::1162.084*39.02] mapped 21689 sequences
# [M::worker_pipeline::1362.541*38.99] mapped 21616 sequences
# [M::worker_pipeline::1576.207*38.31] mapped 21757 sequences
# [M::worker_pipeline::1788.328*38.24] mapped 22496 sequences
# [M::worker_pipeline::1977.860*38.59] mapped 22806 sequences
# [M::worker_pipeline::2170.103*38.70] mapped 22165 sequences
# [M::worker_pipeline::2381.712*38.33] mapped 22957 sequences
# [M::worker_pipeline::2566.540*38.50] mapped 23544 sequences
# [M::worker_pipeline::2727.783*38.87] mapped 23371 sequences
# [M::worker_pipeline::2906.828*39.04] mapped 24068 sequences
# [M::worker_pipeline::3093.745*39.18] mapped 24289 sequences
# [M::worker_pipeline::3343.000*38.73] mapped 19452 sequences
# [M::worker_pipeline::3544.310*38.78] mapped 20038 sequences
# [M::worker_pipeline::3779.800*38.68] mapped 20058 sequences
# [M::worker_pipeline::3984.200*38.67] mapped 20416 sequences
# [M::worker_pipeline::4138.044*38.83] mapped 34327 sequences
# [M::worker_pipeline::4273.452*38.97] mapped 41954 sequences
# [M::worker_pipeline::4401.064*39.15] mapped 41664 sequences
# [M::worker_pipeline::4532.924*39.32] mapped 41677 sequences
# [M::worker_pipeline::4684.672*39.39] mapped 41139 sequences
# [M::worker_pipeline::4843.334*39.62] mapped 38763 sequences
# [M::worker_pipeline::5007.122*39.75] mapped 39457 sequences
# [M::worker_pipeline::5182.820*39.81] mapped 39956 sequences
# [M::worker_pipeline::5334.561*40.00] mapped 40366 sequences
# [M::worker_pipeline::5487.920*40.14] mapped 38901 sequences
# [M::worker_pipeline::5525.582*40.14] mapped 8242 sequences
# [M::main] Version: 2.24-r1122
# [M::main] CMD: minimap2 -a -map-ont -t 48 smle_pzq_es.assembly_rnd2.fasta /master/nplatt/sm_nanopore/results/read_correction/smle_pzq_es/smle_pzq_es.correctedReads.fasta.gz
# [M::main] Real time: 5525.873 sec; CPU: 221794.069 sec; Peak RSS: 23.020 GB
# R3: polish
# [racon::Polisher::initialize] loaded target sequences 2.346187 s
# [racon::Polisher::initialize] loaded sequences 148.885734 s
# [racon::Polisher::initialize] loaded overlaps 41.326534 s
# [racon::Polisher::initialize] aligning overlaps [====================] 14.228298 s
# [racon::Polisher::initialize] transformed data into windows 18.844883 s
# [racon::Polisher::polish] generating consensus [====================] 252.791732 s
# [racon::Polisher::] total = 481.391174 s
# #
# ###################### smle_pzq_er ##################
# R1: map
# [M::mm_idx_gen::8.547*1.66] collected minimizers
# [M::mm_idx_gen::9.878*2.76] sorted minimizers
# [M::main::9.878*2.76] loaded/built the index for 1968 target sequence(s)
# [M::mm_mapopt_update::10.615*2.64] mid_occ = 373
# [M::mm_idx_stat] kmer size: 15; skip: 10; is_hpc: 0; #seq: 1968
# [M::mm_idx_stat::11.119*2.57] distinct minimizers: 30209362 (65.19% are singletons); average occurrences: 2.377; average spacing: 5.323; total length: 382213358
# [M::worker_pipeline::101.212*37.43] mapped 76770 sequences
# [M::worker_pipeline::197.376*39.82] mapped 71320 sequences
# [M::worker_pipeline::292.345*40.90] mapped 73006 sequences
# [M::worker_pipeline::395.987*41.15] mapped 69078 sequences
# [M::worker_pipeline::507.789*39.95] mapped 68270 sequences
# [M::worker_pipeline::605.266*39.60] mapped 76406 sequences
# [M::worker_pipeline::690.203*40.15] mapped 75581 sequences
# [M::worker_pipeline::780.265*40.53] mapped 73411 sequences
# [M::worker_pipeline::874.280*40.80] mapped 73667 sequences
# [M::worker_pipeline::968.959*40.55] mapped 74686 sequences
# [M::worker_pipeline::1064.246*40.48] mapped 77941 sequences
# [M::worker_pipeline::1150.558*40.63] mapped 78752 sequences
# [M::worker_pipeline::1239.019*40.81] mapped 76620 sequences
# [M::worker_pipeline::1294.453*40.67] mapped 43491 sequences
# [M::main] Version: 2.24-r1122
# [M::main] CMD: minimap2 -a -map-ont -t 48 smle_pzq_er.assembly_rnd0.fasta /master/nplatt/sm_nanopore/results/read_correction/smle_pzq_er/smle_pzq_er.correctedReads.fasta.gz
# [M::main] Real time: 1294.799 sec; CPU: 52650.649 sec; Peak RSS: 22.097 GB
# R1: polish
# [racon::Polisher::initialize] loaded target sequences 2.077128 s
# [racon::Polisher::initialize] loaded sequences 65.019206 s
# [racon::Polisher::initialize] loaded overlaps 24.796660 s
# [racon::Polisher::initialize] aligning overlaps [====================] 11.954963 s
# [racon::Polisher::initialize] transformed data into windows 7.371992 s
# [racon::Polisher::polish] generating consensus [====================] 143.387897 s4.845812 s
# [racon::Polisher::] total = 257.503844 s
# #
# R2: map
# [M::mm_idx_gen::7.541*1.69] collected minimizers
# [M::mm_idx_gen::8.788*2.77] sorted minimizers
# [M::main::8.789*2.77] loaded/built the index for 1611 target sequence(s)
# [M::mm_mapopt_update::9.488*2.64] mid_occ = 364
# [M::mm_idx_stat] kmer size: 15; skip: 10; is_hpc: 0; #seq: 1611
# [M::mm_idx_stat::9.973*2.56] distinct minimizers: 30322343 (65.28% are singletons); average occurrences: 2.365; average spacing: 5.321; total length: 381614371
# [M::worker_pipeline::100.131*37.83] mapped 76770 sequences
# [M::worker_pipeline::195.433*39.64] mapped 71320 sequences
# [M::worker_pipeline::286.855*40.64] mapped 73006 sequences
# [M::worker_pipeline::389.978*40.81] mapped 69078 sequences
# [M::worker_pipeline::498.317*39.88] mapped 68270 sequences
# [M::worker_pipeline::592.994*39.57] mapped 76406 sequences
# [M::worker_pipeline::673.276*40.20] mapped 75581 sequences
# [M::worker_pipeline::761.828*40.59] mapped 73411 sequences
# [M::worker_pipeline::855.219*40.80] mapped 73667 sequences
# [M::worker_pipeline::944.630*40.70] mapped 74686 sequences
# [M::worker_pipeline::1034.611*40.65] mapped 77941 sequences
# [M::worker_pipeline::1125.942*40.59] mapped 78752 sequences
# [M::worker_pipeline::1209.989*40.83] mapped 76620 sequences
# [M::worker_pipeline::1262.212*40.77] mapped 43491 sequences
# [M::main] Version: 2.24-r1122
# [M::main] CMD: minimap2 -a -map-ont -t 48 smle_pzq_er.assembly_rnd1.fasta /master/nplatt/sm_nanopore/results/read_correction/smle_pzq_er/smle_pzq_er.correctedReads.fasta.gz
# [M::main] Real time: 1262.587 sec; CPU: 51454.778 sec; Peak RSS: 21.712 GB
# R2: polish
# [racon::Polisher::initialize] loaded target sequences 2.109804 s
# [racon::Polisher::initialize] loaded sequences 65.880837 s
# [racon::Polisher::initialize] loaded overlaps 26.117030 s
# [racon::Polisher::initialize] aligning overlaps [====================] 12.140027 s
# [racon::Polisher::initialize] transformed data into windows 7.580020 s
# [racon::Polisher::polish] generating consensus [====================] 140.047301 s
# [racon::Polisher::] total = 256.554459 s
# #
# R3: map
# [M::mm_idx_gen::7.511*1.70] collected minimizers
# [M::mm_idx_gen::8.833*2.85] sorted minimizers
# [M::main::8.834*2.85] loaded/built the index for 1582 target sequence(s)
# [M::mm_mapopt_update::9.492*2.72] mid_occ = 364
# [M::mm_idx_stat] kmer size: 15; skip: 10; is_hpc: 0; #seq: 1582
# [M::mm_idx_stat::9.977*2.64] distinct minimizers: 30331368 (65.29% are singletons); average occurrences: 2.365; average spacing: 5.321; total length: 381704002
# [M::worker_pipeline::100.601*38.07] mapped 76770 sequences
# [M::worker_pipeline::193.603*40.14] mapped 71320 sequences
# [M::worker_pipeline::286.347*40.77] mapped 73006 sequences
# [M::worker_pipeline::387.207*41.10] mapped 69078 sequences
# [M::worker_pipeline::491.405*40.24] mapped 68270 sequences
# [M::worker_pipeline::584.664*40.02] mapped 76406 sequences
# [M::worker_pipeline::664.283*40.59] mapped 75581 sequences
# [M::worker_pipeline::751.438*41.05] mapped 73411 sequences
# [M::worker_pipeline::844.293*41.29] mapped 73667 sequences
# [M::worker_pipeline::935.497*41.07] mapped 74686 sequences
# [M::worker_pipeline::1024.562*41.09] mapped 77941 sequences
# [M::worker_pipeline::1109.975*41.20] mapped 78752 sequences
# [M::worker_pipeline::1194.609*41.44] mapped 76620 sequences
# [M::worker_pipeline::1245.823*41.34] mapped 43491 sequences
# [M::main] Version: 2.24-r1122
# [M::main] CMD: minimap2 -a -map-ont -t 48 smle_pzq_er.assembly_rnd2.fasta /master/nplatt/sm_nanopore/results/read_correction/smle_pzq_er/smle_pzq_er.correctedReads.fasta.gz
# [M::main] Real time: 1246.252 sec; CPU: 51501.835 sec; Peak RSS: 21.574 GB
# R3: polish
# [racon::Polisher::initialize] loaded target sequences 2.172103 s
# [racon::Polisher::initialize] loaded sequences 66.222945 s
# [racon::Polisher::initialize] loaded overlaps 26.870027 s
# [racon::Polisher::initialize] aligning overlaps [====================] 12.611046 s
# [racon::Polisher::initialize] transformed data into windows 10.259038 s
# [racon::Polisher::polish] generating consensus [====================] 146.096231 s
# [racon::Polisher::] total = 267.307171 s
# #
# ###################### smbre ##################
# R1: map
# [M::mm_idx_gen::7.514*1.69] collected minimizers
# [M::mm_idx_gen::8.769*2.80] sorted minimizers
# [M::main::8.770*2.80] loaded/built the index for 1020 target sequence(s)
# [M::mm_mapopt_update::9.478*2.66] mid_occ = 394
# [M::mm_idx_stat] kmer size: 15; skip: 10; is_hpc: 0; #seq: 1020
# [M::mm_idx_stat::9.978*2.58] distinct minimizers: 30091754 (65.42% are singletons); average occurrences: 2.403; average spacing: 5.324; total length: 384951218
# [M::worker_pipeline::193.150*34.78] mapped 53283 sequences
# [M::worker_pipeline::345.736*38.72] mapped 52871 sequences
# [M::worker_pipeline::512.004*39.90] mapped 48725 sequences
# [M::worker_pipeline::677.763*40.43] mapped 46760 sequences
# [M::worker_pipeline::843.969*40.72] mapped 43965 sequences
# [M::worker_pipeline::1001.822*41.18] mapped 43922 sequences
# [M::worker_pipeline::1163.905*41.65] mapped 42570 sequences
# [M::worker_pipeline::1336.817*41.55] mapped 40977 sequences
# [M::worker_pipeline::1513.143*41.51] mapped 39946 sequences
# [M::worker_pipeline::1676.543*41.50] mapped 46552 sequences
# [M::worker_pipeline::1856.737*41.03] mapped 47237 sequences
# [M::worker_pipeline::2018.012*41.15] mapped 46567 sequences
# [M::worker_pipeline::2178.742*41.25] mapped 46788 sequences
# [M::worker_pipeline::2330.101*41.50] mapped 45522 sequences
# [M::worker_pipeline::2488.746*41.61] mapped 45538 sequences
# [M::worker_pipeline::2634.157*41.77] mapped 45607 sequences
# [M::worker_pipeline::2790.556*41.71] mapped 45182 sequences
# [M::worker_pipeline::2942.096*41.77] mapped 45409 sequences
# [M::worker_pipeline::3073.416*41.84] mapped 44380 sequences
# [M::worker_pipeline::3211.393*41.90] mapped 44938 sequences
# [M::worker_pipeline::3357.080*41.72] mapped 45630 sequences
# [M::worker_pipeline::3498.487*41.47] mapped 40156 sequences
# [M::main] Version: 2.24-r1122
# [M::main] CMD: minimap2 -a -map-ont -t 48 smbre.assembly_rnd0.fasta /master/nplatt/sm_nanopore/results/read_correction/smbre/smbre.correctedReads.fasta.gz
# [M::main] Real time: 3498.906 sec; CPU: 145074.942 sec; Peak RSS: 24.759 GB
# R1: polish
# [racon::Polisher::initialize] loaded target sequences 2.078661 s
# [racon::Polisher::initialize] loaded sequences 107.383010 s
# [racon::Polisher::initialize] loaded overlaps 36.186241 s
# [racon::Polisher::initialize] aligning overlaps [====================] 16.406332 s
# [racon::Polisher::initialize] transformed data into windows 15.943155 s
# [racon::Polisher::polish] generating consensus [====================] 195.406518 s
# [racon::Polisher::] total = 376.592673 s
# #
# R2: map
# [M::mm_idx_gen::7.578*1.70] collected minimizers
# [M::mm_idx_gen::8.792*2.78] sorted minimizers
# [M::main::8.793*2.78] loaded/built the index for 863 target sequence(s)
# [M::mm_mapopt_update::9.495*2.64] mid_occ = 392
# [M::mm_idx_stat] kmer size: 15; skip: 10; is_hpc: 0; #seq: 863
# [M::mm_idx_stat::9.976*2.57] distinct minimizers: 30104826 (65.45% are singletons); average occurrences: 2.399; average spacing: 5.324; total length: 384537830
# [M::worker_pipeline::196.025*35.18] mapped 53283 sequences
# [M::worker_pipeline::348.845*38.96] mapped 52871 sequences
# [M::worker_pipeline::528.009*39.62] mapped 48725 sequences
# [M::worker_pipeline::700.069*39.96] mapped 46760 sequences
# [M::worker_pipeline::874.344*40.26] mapped 43965 sequences
# [M::worker_pipeline::1036.449*40.81] mapped 43922 sequences
# [M::worker_pipeline::1206.986*41.14] mapped 42570 sequences
# [M::worker_pipeline::1380.384*41.19] mapped 40977 sequences
# [M::worker_pipeline::1561.838*41.20] mapped 39946 sequences
# [M::worker_pipeline::1730.506*41.10] mapped 46552 sequences
# [M::worker_pipeline::1911.670*40.70] mapped 47237 sequences
# [M::worker_pipeline::2066.317*41.02] mapped 46567 sequences
# [M::worker_pipeline::2233.712*41.04] mapped 46788 sequences
# [M::worker_pipeline::2394.546*41.20] mapped 45522 sequences
# [M::worker_pipeline::2558.987*41.24] mapped 45538 sequences
# [M::worker_pipeline::2715.758*41.36] mapped 45607 sequences
# [M::worker_pipeline::2871.871*41.39] mapped 45182 sequences
# [M::worker_pipeline::3039.750*41.31] mapped 45409 sequences
# [M::worker_pipeline::3175.911*41.36] mapped 44380 sequences
# [M::worker_pipeline::3327.163*41.34] mapped 44938 sequences
# [M::worker_pipeline::3478.397*41.17] mapped 45630 sequences
# [M::worker_pipeline::3613.450*41.07] mapped 40156 sequences
# [M::main] Version: 2.24-r1122
# [M::main] CMD: minimap2 -a -map-ont -t 48 smbre.assembly_rnd1.fasta /master/nplatt/sm_nanopore/results/read_correction/smbre/smbre.correctedReads.fasta.gz
# [M::main] Real time: 3613.843 sec; CPU: 148414.394 sec; Peak RSS: 23.428 GB
# R2: polish
# [racon::Polisher::initialize] loaded target sequences 2.138405 s
# [racon::Polisher::initialize] loaded sequences 102.947766 s
# [racon::Polisher::initialize] loaded overlaps 25.953495 s
# [racon::Polisher::initialize] aligning overlaps [====================] 12.424720 s
# [racon::Polisher::initialize] transformed data into windows 14.520990 s
# [racon::Polisher::polish] generating consensus [====================] 193.301941 s
# [racon::Polisher::] total = 354.562270 s
# #
# R3: map
# [M::mm_idx_gen::8.107*1.69] collected minimizers
# [M::mm_idx_gen::9.529*2.98] sorted minimizers
# [M::main::9.530*2.98] loaded/built the index for 831 target sequence(s)
# [M::mm_mapopt_update::10.381*2.81] mid_occ = 391
# [M::mm_idx_stat] kmer size: 15; skip: 10; is_hpc: 0; #seq: 831
# [M::mm_idx_stat::10.960*2.72] distinct minimizers: 30104374 (65.45% are singletons); average occurrences: 2.399; average spacing: 5.324; total length: 384487880
# [M::worker_pipeline::191.993*35.65] mapped 53283 sequences
# [M::worker_pipeline::344.222*39.09] mapped 52871 sequences
# [M::worker_pipeline::522.196*39.74] mapped 48725 sequences
# [M::worker_pipeline::690.916*40.17] mapped 46760 sequences
# [M::worker_pipeline::864.704*40.33] mapped 43965 sequences
# [M::worker_pipeline::1021.268*40.83] mapped 43922 sequences
# [M::worker_pipeline::1192.620*41.12] mapped 42570 sequences
# [M::worker_pipeline::1362.209*41.19] mapped 40977 sequences
# [M::worker_pipeline::1537.998*41.34] mapped 39946 sequences
# [M::worker_pipeline::1704.273*41.23] mapped 46552 sequences
# [M::worker_pipeline::1889.321*40.75] mapped 47237 sequences
# [M::worker_pipeline::2048.109*40.89] mapped 46567 sequences
# [M::worker_pipeline::2213.962*40.91] mapped 46788 sequences
# [M::worker_pipeline::2369.793*41.09] mapped 45522 sequences
# [M::worker_pipeline::2533.122*41.16] mapped 45538 sequences
# [M::worker_pipeline::2685.127*41.29] mapped 45607 sequences
# [M::worker_pipeline::2839.448*41.33] mapped 45182 sequences
# [M::worker_pipeline::3000.577*41.33] mapped 45409 sequences
# [M::worker_pipeline::3134.637*41.40] mapped 44380 sequences
# [M::worker_pipeline::3279.134*41.38] mapped 44938 sequences
# [M::worker_pipeline::3422.723*41.27] mapped 45630 sequences
# [M::worker_pipeline::3563.041*41.09] mapped 40156 sequences
# [M::main] Version: 2.24-r1122
# [M::main] CMD: minimap2 -a -map-ont -t 48 smbre.assembly_rnd2.fasta /master/nplatt/sm_nanopore/results/read_correction/smbre/smbre.correctedReads.fasta.gz
# [M::main] Real time: 3563.511 sec; CPU: 146416.730 sec; Peak RSS: 23.257 GB
# R3: polish
# [racon::Polisher::initialize] loaded target sequences 2.310798 s
# [racon::Polisher::initialize] loaded sequences 107.066274 s
# [racon::Polisher::initialize] loaded overlaps 26.866338 s
# [racon::Polisher::initialize] aligning overlaps [====================] 14.815388 s
# [racon::Polisher::initialize] transformed data into windows 16.890523 s
# [racon::Polisher::polish] generating consensus [====================] 188.803997 s
# [racon::Polisher::] total = 360.313372 s
# #
# ###################### smeg ##################
# R1: map
# [M::mm_idx_gen::7.068*1.68] collected minimizers
# [M::mm_idx_gen::8.334*2.85] sorted minimizers
# [M::main::8.334*2.85] loaded/built the index for 1963 target sequence(s)
# [M::mm_mapopt_update::9.029*2.71] mid_occ = 374
# [M::mm_idx_stat] kmer size: 15; skip: 10; is_hpc: 0; #seq: 1963
# [M::mm_idx_stat::9.508*2.62] distinct minimizers: 29693941 (65.87% are singletons); average occurrences: 2.343; average spacing: 5.325; total length: 370379461
# [M::worker_pipeline::150.602*36.83] mapped 46550 sequences
# [M::worker_pipeline::269.723*39.19] mapped 48696 sequences
# [M::worker_pipeline::410.898*39.44] mapped 48598 sequences
# [M::worker_pipeline::548.265*39.24] mapped 46410 sequences
# [M::worker_pipeline::688.176*38.50] mapped 49713 sequences
# [M::worker_pipeline::843.005*38.13] mapped 49778 sequences
# [M::worker_pipeline::979.189*38.40] mapped 48029 sequences
# [M::worker_pipeline::1119.284*38.46] mapped 47397 sequences
# [M::worker_pipeline::1236.508*38.74] mapped 63067 sequences
# [M::worker_pipeline::1343.908*39.18] mapped 69436 sequences
# [M::worker_pipeline::1466.845*39.07] mapped 67208 sequences
# [M::worker_pipeline::1591.167*39.05] mapped 65917 sequences
# [M::worker_pipeline::1608.341*38.89] mapped 7204 sequences
# [M::main] Version: 2.24-r1122
# [M::main] CMD: minimap2 -a -map-ont -t 48 smeg.assembly_rnd0.fasta /master/nplatt/sm_nanopore/results/read_correction/smeg/smeg.correctedReads.fasta.gz
# [M::main] Real time: 1608.539 sec; CPU: 62555.827 sec; Peak RSS: 21.167 GB
# R1: polish
# [racon::Polisher::initialize] loaded target sequences 2.004812 s
# [racon::Polisher::initialize] loaded sequences 57.975932 s
# [racon::Polisher::initialize] loaded overlaps 18.154140 s
# [racon::Polisher::initialize] aligning overlaps [====================] 7.779614 s
# [racon::Polisher::initialize] transformed data into windows 6.775523 s
# [racon::Polisher::polish] generating consensus [====================] 106.537008 s
# [racon::Polisher::] total = 201.228917 s
# #
# R2: map
# [M::mm_idx_gen::7.289*1.65] collected minimizers
# [M::mm_idx_gen::8.646*2.85] sorted minimizers
# [M::main::8.646*2.85] loaded/built the index for 1704 target sequence(s)
# [M::mm_mapopt_update::9.344*2.71] mid_occ = 369
# [M::mm_idx_stat] kmer size: 15; skip: 10; is_hpc: 0; #seq: 1704
# [M::mm_idx_stat::9.822*2.63] distinct minimizers: 29717886 (65.87% are singletons); average occurrences: 2.337; average spacing: 5.324; total length: 369728076
# [M::worker_pipeline::148.591*36.65] mapped 46550 sequences
# [M::worker_pipeline::266.160*39.31] mapped 48696 sequences
# [M::worker_pipeline::398.206*40.43] mapped 48598 sequences
# [M::worker_pipeline::528.110*40.40] mapped 46410 sequences
# [M::worker_pipeline::666.205*39.49] mapped 49713 sequences
# [M::worker_pipeline::818.088*38.86] mapped 49778 sequences
# [M::worker_pipeline::952.898*39.00] mapped 48029 sequences
# [M::worker_pipeline::1090.429*39.05] mapped 47397 sequences
# [M::worker_pipeline::1203.600*39.29] mapped 63067 sequences
# [M::worker_pipeline::1305.587*39.72] mapped 69436 sequences
# [M::worker_pipeline::1426.536*39.66] mapped 67208 sequences
# [M::worker_pipeline::1542.291*39.80] mapped 65917 sequences
# [M::worker_pipeline::1559.713*39.65] mapped 7204 sequences
# [M::main] Version: 2.24-r1122
# [M::main] CMD: minimap2 -a -map-ont -t 48 smeg.assembly_rnd1.fasta /master/nplatt/sm_nanopore/results/read_correction/smeg/smeg.correctedReads.fasta.gz
# [M::main] Real time: 1560.060 sec; CPU: 61840.668 sec; Peak RSS: 22.912 GB
# R2: polish
# [racon::Polisher::initialize] loaded target sequences 2.715573 s
# [racon::Polisher::initialize] loaded sequences 57.372261 s
# [racon::Polisher::initialize] loaded overlaps 16.191489 s
# [racon::Polisher::initialize] aligning overlaps [====================] 8.778752 s
# [racon::Polisher::initialize] transformed data into windows 7.200109 s
# [racon::Polisher::polish] generating consensus [====================] 109.529461 s
# [racon::Polisher::] total = 203.975579 s
# #
# R3: map
# [M::mm_idx_gen::7.185*1.67] collected minimizers
# [M::mm_idx_gen::8.396*2.79] sorted minimizers
# [M::main::8.397*2.79] loaded/built the index for 1669 target sequence(s)
# [M::mm_mapopt_update::9.086*2.65] mid_occ = 368
# [M::mm_idx_stat] kmer size: 15; skip: 10; is_hpc: 0; #seq: 1669
# [M::mm_idx_stat::9.561*2.57] distinct minimizers: 29717896 (65.88% are singletons); average occurrences: 2.336; average spacing: 5.324; total length: 369543290
# [M::worker_pipeline::149.730*38.03] mapped 46550 sequences
# [M::worker_pipeline::273.541*39.97] mapped 48696 sequences
# [M::worker_pipeline::413.320*40.10] mapped 48598 sequences
# [M::worker_pipeline::544.038*40.43] mapped 46410 sequences
# [M::worker_pipeline::683.224*39.58] mapped 49713 sequences
# [M::worker_pipeline::832.897*39.42] mapped 49778 sequences
# [M::worker_pipeline::967.910*39.63] mapped 48029 sequences
# [M::worker_pipeline::1108.349*39.56] mapped 47397 sequences
# [M::worker_pipeline::1226.402*39.75] mapped 63067 sequences
# [M::worker_pipeline::1329.992*40.16] mapped 69436 sequences
# [M::worker_pipeline::1454.251*40.01] mapped 67208 sequences
# [M::worker_pipeline::1574.498*40.08] mapped 65917 sequences
# [M::worker_pipeline::1591.432*39.93] mapped 7204 sequences
# [M::main] Version: 2.24-r1122
# [M::main] CMD: minimap2 -a -map-ont -t 48 smeg.assembly_rnd2.fasta /master/nplatt/sm_nanopore/results/read_correction/smeg/smeg.correctedReads.fasta.gz
# [M::main] Real time: 1591.774 sec; CPU: 63541.456 sec; Peak RSS: 21.523 GB
# R3: polish
# [racon::Polisher::initialize] loaded target sequences 2.071946 s
# [racon::Polisher::initialize] loaded sequences 58.422955 s
# [racon::Polisher::initialize] loaded overlaps 22.068410 s
# [racon::Polisher::initialize] aligning overlaps [====================] 6.597411 s
# [racon::Polisher::initialize] transformed data into windows 6.582953 s
# [racon::Polisher::polish] generating consensus [====================] 108.250975 s
# [racon::Polisher::] total = 206.464460 s
# #

# %%
## Genome contamination

# %%
mkdir -p ${PROJ_DIR}/data/remove_contamination && cd ${PROJ_DIR}/data/remove_contamination

# %%
#https://github.com/timkahlke/BASTA/wiki/3.-BASTA-Usage

# %%
# %%bash
#
# conda activate basta_py3
#
# mkdir -p ${PROJ_DIR}/data/remove_contamination && cd ${PROJ_DIR}/data/remove_contamination
#
# genome_updater.sh \
#     -g "" \
#     -d "refseq" \
#     -c "representative genome" \
#     -l "complete genome,chromosome" \
#     -f "genomic.fna.gz,assembly_report.txt" \
#     -o "refseq_216_fas" \
#     -b "v1" \
#     -a \
#     -A species:1 \
#     -m \
#     -u \
#     -r \
#     -p \
#     -t 48
#
# #uncompress for kraken2
# cd refseq_216_fas/v1/files
#
# ls *.gz | parallel -j 48 gunzip {}

# %%
#create blast database
cat *.fas >refseq_216.fas

# %%
makeblastdb -dbtype nucle -in

# %%
blastm -outfmt 6 -in <assembly> -out <assembly>.blastn --threads 48

# %%
./bin/basta taxonomy

# %%
./bin/basta download gb

# %%
./bin/basta sequence INPUT_FILE OUTPUT_FILE MAPPING_FILE_TYPE

# %%
./scripts/filter_basta_fasta.py [options] FASTA_FILE FILTERED_OUTPUT_FILE NAME_OF_TAXON BASTA_FILE

# %% [markdown]
# #

# %% [markdown]
# ## genome quality

# %%
Path("{}/results/busco".format(proj_dir)).mkdir(parents=True, exist_ok=True)
os.chdir("{}/results/busco".format(proj_dir))

# %%
for sample in samples:
    assembly = "{}/results/polish_assembly/{}.assembly_rnd3.fasta".format(proj_dir, sample)
    # !conda run -n busco --cwd . --live-stream busco -i {assembly} --auto-lineage-euk -c 48 -o {sample} -m genome
# Out:
# 2023-02-07 16:58:55 INFO:	***** Start a BUSCO v5.4.3 analysis, current time: 02/07/2023 16:58:55 *****
# 2023-02-07 16:58:55 INFO:	Configuring BUSCO with local environment
# 2023-02-07 16:58:55 INFO:	Mode is genome
# 2023-02-07 16:58:55 INFO:	Downloading information on latest versions of BUSCO data...
# 2023-02-07 16:58:57 INFO:	Input file is /master/nplatt/sm_nanopore/results/polish_assembly/smor.assembly_rnd3.fasta
# 2023-02-07 16:58:57 INFO:	No lineage specified. Running lineage auto selector.
#
# 2023-02-07 16:58:57 INFO:	***** Starting Auto Select Lineage *****
# 	This process runs BUSCO on the generic lineage datasets for the domains archaea, bacteria and eukaryota. Once the optimal domain is selected, BUSCO automatically attempts to find the most appropriate BUSCO dataset to use based on phylogenetic placement.
# 	--auto-lineage-euk and --auto-lineage-prok are also available if you know your input assembly is, or is not, an eukaryote. See the user guide for more information.
# 	A reminder: Busco evaluations are valid when an appropriate dataset is used, i.e., the dataset belongs to the lineage of the species to test. Because of overlapping markers/spurious matches among domains, busco matches in another domain do not necessarily mean that your genome/proteome contains sequences from this domain. However, a high busco score in multiple domains might help you identify possible contaminations.
# 2023-02-07 16:58:57 INFO:	Downloading file 'https://busco-data.ezlab.org/v5/data/lineages/eukaryota_odb10.2020-09-10.tar.gz'
# 2023-02-07 16:59:10 INFO:	Decompressing file '/master/nplatt/sm_nanopore/results/busco/busco_downloads/lineages/eukaryota_odb10.tar.gz'
# 2023-02-07 16:59:16 INFO:	Running BUSCO using lineage dataset eukaryota_odb10 (eukaryota, 2020-09-10)
# 2023-02-07 16:59:16 INFO:	Running 1 job(s) on bbtools, starting at 02/07/2023 16:59:16
# 2023-02-07 16:59:22 INFO:	[bbtools]	1 of 1 task(s) completed
# 2023-02-07 16:59:25 INFO:	Running 1 job(s) on metaeuk, starting at 02/07/2023 16:59:25
# 2023-02-07 17:06:26 INFO:	[metaeuk]	1 of 1 task(s) completed
# 2023-02-07 17:06:39 INFO:	***** Run HMMER on gene sequences *****
# 2023-02-07 17:06:39 INFO:	Running 255 job(s) on hmmsearch, starting at 02/07/2023 17:06:39
# 2023-02-07 17:06:45 INFO:	[hmmsearch]	26 of 255 task(s) completed
# 2023-02-07 17:06:45 INFO:	[hmmsearch]	51 of 255 task(s) completed
# 2023-02-07 17:06:45 INFO:	[hmmsearch]	77 of 255 task(s) completed
# 2023-02-07 17:06:45 INFO:	[hmmsearch]	102 of 255 task(s) completed
# 2023-02-07 17:06:45 INFO:	[hmmsearch]	128 of 255 task(s) completed
# 2023-02-07 17:06:45 INFO:	[hmmsearch]	153 of 255 task(s) completed
# 2023-02-07 17:06:45 INFO:	[hmmsearch]	179 of 255 task(s) completed
# 2023-02-07 17:06:45 INFO:	[hmmsearch]	204 of 255 task(s) completed
# 2023-02-07 17:06:46 INFO:	[hmmsearch]	230 of 255 task(s) completed
# 2023-02-07 17:06:46 INFO:	[hmmsearch]	255 of 255 task(s) completed
# 2023-02-07 17:06:47 INFO:	Results:	C:82.0%[S:81.2%,D:0.8%],F:10.2%,M:7.8%,n:255
#
# 2023-02-07 17:06:47 INFO:	Extracting missing and fragmented buscos from the file refseq_db.faa...
# 2023-02-07 17:06:51 INFO:	Running 1 job(s) on metaeuk, starting at 02/07/2023 17:06:51
# 2023-02-07 17:17:48 INFO:	[metaeuk]	1 of 1 task(s) completed
# 2023-02-07 17:17:50 INFO:	***** Run HMMER on gene sequences *****
# 2023-02-07 17:17:50 INFO:	Running 46 job(s) on hmmsearch, starting at 02/07/2023 17:17:50
# 2023-02-07 17:17:55 INFO:	[hmmsearch]	5 of 46 task(s) completed
# 2023-02-07 17:17:56 INFO:	[hmmsearch]	10 of 46 task(s) completed
# 2023-02-07 17:17:56 INFO:	[hmmsearch]	14 of 46 task(s) completed
# 2023-02-07 17:17:56 INFO:	[hmmsearch]	19 of 46 task(s) completed
# 2023-02-07 17:17:56 INFO:	[hmmsearch]	23 of 46 task(s) completed
# 2023-02-07 17:17:56 INFO:	[hmmsearch]	28 of 46 task(s) completed
# 2023-02-07 17:17:56 INFO:	[hmmsearch]	33 of 46 task(s) completed
# 2023-02-07 17:17:56 INFO:	[hmmsearch]	37 of 46 task(s) completed
# 2023-02-07 17:17:56 INFO:	[hmmsearch]	42 of 46 task(s) completed
# 2023-02-07 17:17:56 INFO:	[hmmsearch]	46 of 46 task(s) completed
# 2023-02-07 17:17:58 INFO:	Validating exons and removing overlapping matches
# 2023-02-07 17:18:00 INFO:	Results:	C:83.6%[S:82.4%,D:1.2%],F:9.0%,M:7.4%,n:255
#
# 2023-02-07 17:18:13 INFO:	eukaryota_odb10 selected
#
# 2023-02-07 17:18:13 INFO:	***** Searching tree for chosen lineage to find best taxonomic match *****
#
# 2023-02-07 17:18:16 INFO:	Extract markers...
# 2023-02-07 17:18:16 INFO:	Downloading file 'https://busco-data.ezlab.org/v5/data/placement_files/list_of_reference_markers.eukaryota_odb10.2019-12-16.txt.tar.gz'
# 2023-02-07 17:18:17 INFO:	Decompressing file '/master/nplatt/sm_nanopore/results/busco/busco_downloads/placement_files/list_of_reference_markers.eukaryota_odb10.2019-12-16.txt.tar.gz'
# 2023-02-07 17:18:17 INFO:	Downloading file 'https://busco-data.ezlab.org/v5/data/placement_files/tree.eukaryota_odb10.2019-12-16.nwk.tar.gz'
# 2023-02-07 17:18:18 INFO:	Decompressing file '/master/nplatt/sm_nanopore/results/busco/busco_downloads/placement_files/tree.eukaryota_odb10.2019-12-16.nwk.tar.gz'
# 2023-02-07 17:18:18 INFO:	Downloading file 'https://busco-data.ezlab.org/v5/data/placement_files/tree_metadata.eukaryota_odb10.2019-12-16.txt.tar.gz'
# 2023-02-07 17:18:19 INFO:	Decompressing file '/master/nplatt/sm_nanopore/results/busco/busco_downloads/placement_files/tree_metadata.eukaryota_odb10.2019-12-16.txt.tar.gz'
# 2023-02-07 17:18:19 INFO:	Downloading file 'https://busco-data.ezlab.org/v5/data/placement_files/supermatrix.aln.eukaryota_odb10.2019-12-16.faa.tar.gz'
# 2023-02-07 17:18:26 INFO:	Decompressing file '/master/nplatt/sm_nanopore/results/busco/busco_downloads/placement_files/supermatrix.aln.eukaryota_odb10.2019-12-16.faa.tar.gz'
# 2023-02-07 17:18:27 INFO:	Downloading file 'https://busco-data.ezlab.org/v5/data/placement_files/mapping_taxids-busco_dataset_name.eukaryota_odb10.2019-12-16.txt.tar.gz'
# 2023-02-07 17:18:27 INFO:	Decompressing file '/master/nplatt/sm_nanopore/results/busco/busco_downloads/placement_files/mapping_taxids-busco_dataset_name.eukaryota_odb10.2019-12-16.txt.tar.gz'
# 2023-02-07 17:18:27 INFO:	Downloading file 'https://busco-data.ezlab.org/v5/data/placement_files/mapping_taxid-lineage.eukaryota_odb10.2019-12-16.txt.tar.gz'
# 2023-02-07 17:18:29 INFO:	Decompressing file '/master/nplatt/sm_nanopore/results/busco/busco_downloads/placement_files/mapping_taxid-lineage.eukaryota_odb10.2019-12-16.txt.tar.gz'
# 2023-02-07 17:18:29 INFO:	Place the markers on the reference tree...
# 2023-02-07 17:18:29 INFO:	Running 1 job(s) on sepp, starting at 02/07/2023 17:18:29
# 2023-02-07 17:19:32 INFO:	[sepp]	1 of 1 task(s) completed
# 2023-02-07 17:19:35 INFO:	Lineage metazoa is selected, supported by 48 markers out of 91
# 2023-02-07 17:19:35 INFO:	Downloading file 'https://busco-data.ezlab.org/v5/data/lineages/metazoa_odb10.2021-02-24.tar.gz'
# 2023-02-07 17:19:48 INFO:	Decompressing file '/master/nplatt/sm_nanopore/results/busco/busco_downloads/lineages/metazoa_odb10.tar.gz'
# 2023-02-07 17:20:01 INFO:	Running BUSCO using lineage dataset metazoa_odb10 (eukaryota, 2021-02-17)
# 2023-02-07 17:20:01 INFO:	Running 1 job(s) on bbtools, starting at 02/07/2023 17:20:01
# 2023-02-07 17:20:08 INFO:	[bbtools]	1 of 1 task(s) completed
# 2023-02-07 17:20:11 INFO:	Running 1 job(s) on metaeuk, starting at 02/07/2023 17:20:11
# 2023-02-07 17:26:52 INFO:	[metaeuk]	1 of 1 task(s) completed
# 2023-02-07 17:27:09 INFO:	***** Run HMMER on gene sequences *****
# 2023-02-07 17:27:09 INFO:	Running 954 job(s) on hmmsearch, starting at 02/07/2023 17:27:09
# 2023-02-07 17:27:15 INFO:	[hmmsearch]	96 of 954 task(s) completed
# 2023-02-07 17:27:15 INFO:	[hmmsearch]	191 of 954 task(s) completed
# 2023-02-07 17:27:15 INFO:	[hmmsearch]	287 of 954 task(s) completed
# 2023-02-07 17:27:15 INFO:	[hmmsearch]	287 of 954 task(s) completed
# 2023-02-07 17:27:16 INFO:	[hmmsearch]	382 of 954 task(s) completed
# 2023-02-07 17:27:16 INFO:	[hmmsearch]	478 of 954 task(s) completed
# 2023-02-07 17:27:17 INFO:	[hmmsearch]	764 of 954 task(s) completed
# 2023-02-07 17:27:17 INFO:	[hmmsearch]	859 of 954 task(s) completed
# 2023-02-07 17:27:18 INFO:	[hmmsearch]	954 of 954 task(s) completed
# 2023-02-07 17:27:21 INFO:	Extracting missing and fragmented buscos from the file refseq_db.faa...
# 2023-02-07 17:27:37 INFO:	Running 1 job(s) on metaeuk, starting at 02/07/2023 17:27:37
# 2023-02-07 17:39:06 INFO:	[metaeuk]	1 of 1 task(s) completed
# 2023-02-07 17:39:14 INFO:	***** Run HMMER on gene sequences *****
# 2023-02-07 17:39:14 INFO:	Running 327 job(s) on hmmsearch, starting at 02/07/2023 17:39:14
# 2023-02-07 17:39:19 INFO:	[hmmsearch]	33 of 327 task(s) completed
# 2023-02-07 17:39:20 INFO:	[hmmsearch]	66 of 327 task(s) completed
# 2023-02-07 17:39:20 INFO:	[hmmsearch]	99 of 327 task(s) completed
# 2023-02-07 17:39:20 INFO:	[hmmsearch]	131 of 327 task(s) completed
# 2023-02-07 17:39:21 INFO:	[hmmsearch]	164 of 327 task(s) completed
# 2023-02-07 17:39:21 INFO:	[hmmsearch]	197 of 327 task(s) completed
# 2023-02-07 17:39:21 INFO:	[hmmsearch]	229 of 327 task(s) completed
# 2023-02-07 17:39:21 INFO:	[hmmsearch]	262 of 327 task(s) completed
# 2023-02-07 17:39:22 INFO:	[hmmsearch]	295 of 327 task(s) completed
# 2023-02-07 17:39:22 INFO:	[hmmsearch]	327 of 327 task(s) completed
# 2023-02-07 17:39:31 INFO:	Validating exons and removing overlapping matches
# 2023-02-07 17:39:36 INFO:	Results:	C:68.1%[S:66.8%,D:1.3%],F:7.1%,M:24.8%,n:954
#
# 2023-02-07 17:40:05 INFO:
#
# 	--------------------------------------------------
# 	|Results from generic domain eukaryota_odb10      |
# 	--------------------------------------------------
# 	|C:83.6%[S:82.4%,D:1.2%],F:9.0%,M:7.4%,n:255      |
# 	|213	Complete BUSCOs (C)                       |
# 	|210	Complete and single-copy BUSCOs (S)       |
# 	|3	Complete and duplicated BUSCOs (D)        |
# 	|23	Fragmented BUSCOs (F)                     |
# 	|19	Missing BUSCOs (M)                        |
# 	|255	Total BUSCO groups searched               |
# 	--------------------------------------------------
#
# 	--------------------------------------------------
# 	|Results from dataset metazoa_odb10               |
# 	--------------------------------------------------
# 	|C:68.1%[S:66.8%,D:1.3%],F:7.1%,M:24.8%,n:954     |
# 	|649	Complete BUSCOs (C)                       |
# 	|637	Complete and single-copy BUSCOs (S)       |
# 	|12	Complete and duplicated BUSCOs (D)        |
# 	|68	Fragmented BUSCOs (F)                     |
# 	|237	Missing BUSCOs (M)                        |
# 	|954	Total BUSCO groups searched               |
# 	--------------------------------------------------
# 2023-02-07 17:40:05 INFO:	BUSCO analysis done. Total running time: 2468 seconds
# 2023-02-07 17:40:05 INFO:	Results written in /master/nplatt/sm_nanopore/results/busco/smor
# 2023-02-07 17:40:05 INFO:	For assistance with interpreting the results, please consult the userguide: https://busco.ezlab.org/busco_userguide.html
#
# 2023-02-07 17:40:05 INFO:	Visit this page https://gitlab.com/ezlab/busco#how-to-cite-busco to see how to cite BUSCO
# 2023-02-07 17:40:08 INFO:	***** Start a BUSCO v5.4.3 analysis, current time: 02/07/2023 17:40:08 *****
# 2023-02-07 17:40:08 INFO:	Configuring BUSCO with local environment
# 2023-02-07 17:40:08 INFO:	Mode is genome
# 2023-02-07 17:40:08 INFO:	Downloading information on latest versions of BUSCO data...
# 2023-02-07 17:40:11 INFO:	Input file is /master/nplatt/sm_nanopore/results/polish_assembly/smle_pzq_es.assembly_rnd3.fasta
# 2023-02-07 17:40:11 INFO:	No lineage specified. Running lineage auto selector.
#
# 2023-02-07 17:40:11 INFO:	***** Starting Auto Select Lineage *****
# 	This process runs BUSCO on the generic lineage datasets for the domains archaea, bacteria and eukaryota. Once the optimal domain is selected, BUSCO automatically attempts to find the most appropriate BUSCO dataset to use based on phylogenetic placement.
# 	--auto-lineage-euk and --auto-lineage-prok are also available if you know your input assembly is, or is not, an eukaryote. See the user guide for more information.
# 	A reminder: Busco evaluations are valid when an appropriate dataset is used, i.e., the dataset belongs to the lineage of the species to test. Because of overlapping markers/spurious matches among domains, busco matches in another domain do not necessarily mean that your genome/proteome contains sequences from this domain. However, a high busco score in multiple domains might help you identify possible contaminations.
# 2023-02-07 17:40:14 INFO:	Running BUSCO using lineage dataset eukaryota_odb10 (eukaryota, 2020-09-10)
# 2023-02-07 17:40:14 INFO:	Running 1 job(s) on bbtools, starting at 02/07/2023 17:40:14
# 2023-02-07 17:40:17 INFO:	[bbtools]	1 of 1 task(s) completed
# 2023-02-07 17:40:17 INFO:	Running 1 job(s) on metaeuk, starting at 02/07/2023 17:40:17
# 2023-02-07 17:47:21 INFO:	[metaeuk]	1 of 1 task(s) completed
# 2023-02-07 17:47:32 INFO:	***** Run HMMER on gene sequences *****
# 2023-02-07 17:47:32 INFO:	Running 255 job(s) on hmmsearch, starting at 02/07/2023 17:47:32
# 2023-02-07 17:47:37 INFO:	[hmmsearch]	51 of 255 task(s) completed
# 2023-02-07 17:47:37 INFO:	[hmmsearch]	77 of 255 task(s) completed
# 2023-02-07 17:47:38 INFO:	[hmmsearch]	102 of 255 task(s) completed
# 2023-02-07 17:47:38 INFO:	[hmmsearch]	128 of 255 task(s) completed
# 2023-02-07 17:47:38 INFO:	[hmmsearch]	153 of 255 task(s) completed
# 2023-02-07 17:47:38 INFO:	[hmmsearch]	179 of 255 task(s) completed
# 2023-02-07 17:47:38 INFO:	[hmmsearch]	204 of 255 task(s) completed
# 2023-02-07 17:47:38 INFO:	[hmmsearch]	230 of 255 task(s) completed
# 2023-02-07 17:47:38 INFO:	[hmmsearch]	255 of 255 task(s) completed
# 2023-02-07 17:47:39 INFO:	Results:	C:87.5%[S:85.9%,D:1.6%],F:6.7%,M:5.8%,n:255
#
# 2023-02-07 17:47:39 INFO:	Extracting missing and fragmented buscos from the file refseq_db.faa...
# 2023-02-07 17:47:43 INFO:	Running 1 job(s) on metaeuk, starting at 02/07/2023 17:47:43
# 2023-02-07 17:57:41 INFO:	[metaeuk]	1 of 1 task(s) completed
# 2023-02-07 17:57:43 INFO:	***** Run HMMER on gene sequences *****
# 2023-02-07 17:57:43 INFO:	Running 32 job(s) on hmmsearch, starting at 02/07/2023 17:57:43
# 2023-02-07 17:57:49 INFO:	[hmmsearch]	4 of 32 task(s) completed
# 2023-02-07 17:57:49 INFO:	[hmmsearch]	7 of 32 task(s) completed
# 2023-02-07 17:57:49 INFO:	[hmmsearch]	10 of 32 task(s) completed
# 2023-02-07 17:57:49 INFO:	[hmmsearch]	13 of 32 task(s) completed
# 2023-02-07 17:57:49 INFO:	[hmmsearch]	17 of 32 task(s) completed
# 2023-02-07 17:57:49 INFO:	[hmmsearch]	23 of 32 task(s) completed
# 2023-02-07 17:57:49 INFO:	[hmmsearch]	26 of 32 task(s) completed
# 2023-02-07 17:57:49 INFO:	[hmmsearch]	29 of 32 task(s) completed
# 2023-02-07 17:57:49 INFO:	[hmmsearch]	32 of 32 task(s) completed
# 2023-02-07 17:57:51 INFO:	Validating exons and removing overlapping matches
# 2023-02-07 17:57:53 INFO:	Results:	C:88.3%[S:86.7%,D:1.6%],F:6.3%,M:5.4%,n:255
#
# 2023-02-07 17:58:05 INFO:	eukaryota_odb10 selected
#
# 2023-02-07 17:58:05 INFO:	***** Searching tree for chosen lineage to find best taxonomic match *****
#
# 2023-02-07 17:58:06 INFO:	Extract markers...
# 2023-02-07 17:58:06 INFO:	Place the markers on the reference tree...
# 2023-02-07 17:58:06 INFO:	Running 1 job(s) on sepp, starting at 02/07/2023 17:58:06
# 2023-02-07 17:59:09 INFO:	[sepp]	1 of 1 task(s) completed
# 2023-02-07 17:59:11 INFO:	Lineage metazoa is selected, supported by 52 markers out of 92
# 2023-02-07 17:59:11 WARNING:	The file or folder /master/nplatt/sm_nanopore/results/busco/busco_downloads/lineages/metazoa_odb10 is not the last available version. To update all data files to the last version, add the parameter --update-data in your next run.
# 2023-02-07 17:59:12 INFO:	Running BUSCO using lineage dataset metazoa_odb10 (eukaryota, 2021-02-17)
# 2023-02-07 17:59:12 INFO:	Running 1 job(s) on bbtools, starting at 02/07/2023 17:59:12
# 2023-02-07 17:59:18 INFO:	[bbtools]	1 of 1 task(s) completed
# 2023-02-07 17:59:18 INFO:	Running 1 job(s) on metaeuk, starting at 02/07/2023 17:59:18
# 2023-02-07 18:06:04 INFO:	[metaeuk]	1 of 1 task(s) completed
# 2023-02-07 18:06:18 INFO:	***** Run HMMER on gene sequences *****
# 2023-02-07 18:06:18 INFO:	Running 954 job(s) on hmmsearch, starting at 02/07/2023 18:06:18
# 2023-02-07 18:06:25 INFO:	[hmmsearch]	96 of 954 task(s) completed
# 2023-02-07 18:06:26 INFO:	[hmmsearch]	191 of 954 task(s) completed
# 2023-02-07 18:06:26 INFO:	[hmmsearch]	382 of 954 task(s) completed
# 2023-02-07 18:06:26 INFO:	[hmmsearch]	478 of 954 task(s) completed
# 2023-02-07 18:06:27 INFO:	[hmmsearch]	573 of 954 task(s) completed
# 2023-02-07 18:06:27 INFO:	[hmmsearch]	764 of 954 task(s) completed
# 2023-02-07 18:06:27 INFO:	[hmmsearch]	764 of 954 task(s) completed
# 2023-02-07 18:06:27 INFO:	[hmmsearch]	859 of 954 task(s) completed
# 2023-02-07 18:06:29 INFO:	[hmmsearch]	954 of 954 task(s) completed
# 2023-02-07 18:06:32 INFO:	Extracting missing and fragmented buscos from the file refseq_db.faa...
# 2023-02-07 18:06:46 INFO:	Running 1 job(s) on metaeuk, starting at 02/07/2023 18:06:46
# 2023-02-07 18:18:18 INFO:	[metaeuk]	1 of 1 task(s) completed
# 2023-02-07 18:18:24 INFO:	***** Run HMMER on gene sequences *****
# 2023-02-07 18:18:24 INFO:	Running 302 job(s) on hmmsearch, starting at 02/07/2023 18:18:24
# 2023-02-07 18:18:29 INFO:	[hmmsearch]	31 of 302 task(s) completed
# 2023-02-07 18:18:29 INFO:	[hmmsearch]	61 of 302 task(s) completed
# 2023-02-07 18:18:29 INFO:	[hmmsearch]	91 of 302 task(s) completed
# 2023-02-07 18:18:29 INFO:	[hmmsearch]	121 of 302 task(s) completed
# 2023-02-07 18:18:30 INFO:	[hmmsearch]	151 of 302 task(s) completed
# 2023-02-07 18:18:30 INFO:	[hmmsearch]	182 of 302 task(s) completed
# 2023-02-07 18:18:30 INFO:	[hmmsearch]	182 of 302 task(s) completed
# 2023-02-07 18:18:30 INFO:	[hmmsearch]	212 of 302 task(s) completed
# 2023-02-07 18:18:30 INFO:	[hmmsearch]	242 of 302 task(s) completed
# 2023-02-07 18:18:30 INFO:	[hmmsearch]	272 of 302 task(s) completed
# 2023-02-07 18:18:30 INFO:	[hmmsearch]	302 of 302 task(s) completed
# 2023-02-07 18:18:40 INFO:	Validating exons and removing overlapping matches
# 2023-02-07 18:18:45 INFO:	Results:	C:69.6%[S:68.0%,D:1.6%],F:6.6%,M:23.8%,n:954
#
# 2023-02-07 18:19:04 INFO:
#
# 	--------------------------------------------------
# 	|Results from generic domain eukaryota_odb10      |
# 	--------------------------------------------------
# 	|C:88.3%[S:86.7%,D:1.6%],F:6.3%,M:5.4%,n:255      |
# 	|225	Complete BUSCOs (C)                       |
# 	|221	Complete and single-copy BUSCOs (S)       |
# 	|4	Complete and duplicated BUSCOs (D)        |
# 	|16	Fragmented BUSCOs (F)                     |
# 	|14	Missing BUSCOs (M)                        |
# 	|255	Total BUSCO groups searched               |
# 	--------------------------------------------------
#
# 	--------------------------------------------------
# 	|Results from dataset metazoa_odb10               |
# 	--------------------------------------------------
# 	|C:69.6%[S:68.0%,D:1.6%],F:6.6%,M:23.8%,n:954     |
# 	|664	Complete BUSCOs (C)                       |
# 	|649	Complete and single-copy BUSCOs (S)       |
# 	|15	Complete and duplicated BUSCOs (D)        |
# 	|63	Fragmented BUSCOs (F)                     |
# 	|227	Missing BUSCOs (M)                        |
# 	|954	Total BUSCO groups searched               |
# 	--------------------------------------------------
# 2023-02-07 18:19:04 INFO:	BUSCO analysis done with WARNING(s). Total running time: 2333 seconds
#
# ***** Summary of warnings: *****
# 2023-02-07 17:59:11 WARNING:busco.BuscoDownloadManager	The file or folder /master/nplatt/sm_nanopore/results/busco/busco_downloads/lineages/metazoa_odb10 is not the last available version. To update all data files to the last version, add the parameter --update-data in your next run.
#
# 2023-02-07 18:19:04 INFO:	Results written in /master/nplatt/sm_nanopore/results/busco/smle_pzq_es
# 2023-02-07 18:19:04 INFO:	For assistance with interpreting the results, please consult the userguide: https://busco.ezlab.org/busco_userguide.html
#
# 2023-02-07 18:19:04 INFO:	Visit this page https://gitlab.com/ezlab/busco#how-to-cite-busco to see how to cite BUSCO
# 2023-02-07 18:19:07 INFO:	***** Start a BUSCO v5.4.3 analysis, current time: 02/07/2023 18:19:07 *****
# 2023-02-07 18:19:07 INFO:	Configuring BUSCO with local environment
# 2023-02-07 18:19:07 INFO:	Mode is genome
# 2023-02-07 18:19:07 INFO:	Downloading information on latest versions of BUSCO data...
# 2023-02-07 18:19:10 INFO:	Input file is /master/nplatt/sm_nanopore/results/polish_assembly/smle_pzq_er.assembly_rnd3.fasta
# 2023-02-07 18:19:10 INFO:	No lineage specified. Running lineage auto selector.
#
# 2023-02-07 18:19:10 INFO:	***** Starting Auto Select Lineage *****
# 	This process runs BUSCO on the generic lineage datasets for the domains archaea, bacteria and eukaryota. Once the optimal domain is selected, BUSCO automatically attempts to find the most appropriate BUSCO dataset to use based on phylogenetic placement.
# 	--auto-lineage-euk and --auto-lineage-prok are also available if you know your input assembly is, or is not, an eukaryote. See the user guide for more information.
# 	A reminder: Busco evaluations are valid when an appropriate dataset is used, i.e., the dataset belongs to the lineage of the species to test. Because of overlapping markers/spurious matches among domains, busco matches in another domain do not necessarily mean that your genome/proteome contains sequences from this domain. However, a high busco score in multiple domains might help you identify possible contaminations.
# 2023-02-07 18:19:12 INFO:	Running BUSCO using lineage dataset eukaryota_odb10 (eukaryota, 2020-09-10)
# 2023-02-07 18:19:12 INFO:	Running 1 job(s) on bbtools, starting at 02/07/2023 18:19:12
# 2023-02-07 18:19:17 INFO:	[bbtools]	1 of 1 task(s) completed
# 2023-02-07 18:19:17 INFO:	Running 1 job(s) on metaeuk, starting at 02/07/2023 18:19:17
# 2023-02-07 18:26:13 INFO:	[metaeuk]	1 of 1 task(s) completed
# 2023-02-07 18:26:28 INFO:	***** Run HMMER on gene sequences *****
# 2023-02-07 18:26:28 INFO:	Running 255 job(s) on hmmsearch, starting at 02/07/2023 18:26:28
# 2023-02-07 18:26:33 INFO:	[hmmsearch]	26 of 255 task(s) completed
# 2023-02-07 18:26:34 INFO:	[hmmsearch]	51 of 255 task(s) completed
# 2023-02-07 18:26:34 INFO:	[hmmsearch]	77 of 255 task(s) completed
# 2023-02-07 18:26:34 INFO:	[hmmsearch]	102 of 255 task(s) completed
# 2023-02-07 18:26:34 INFO:	[hmmsearch]	128 of 255 task(s) completed
# 2023-02-07 18:26:34 INFO:	[hmmsearch]	153 of 255 task(s) completed
# 2023-02-07 18:26:34 INFO:	[hmmsearch]	179 of 255 task(s) completed
# 2023-02-07 18:26:34 INFO:	[hmmsearch]	230 of 255 task(s) completed
# 2023-02-07 18:26:34 INFO:	[hmmsearch]	255 of 255 task(s) completed
# 2023-02-07 18:26:35 INFO:	Results:	C:79.3%[S:77.3%,D:2.0%],F:11.0%,M:9.7%,n:255
#
# 2023-02-07 18:26:35 INFO:	Extracting missing and fragmented buscos from the file refseq_db.faa...
# 2023-02-07 18:26:40 INFO:	Running 1 job(s) on metaeuk, starting at 02/07/2023 18:26:40
# 2023-02-07 18:38:04 INFO:	[metaeuk]	1 of 1 task(s) completed
# 2023-02-07 18:38:10 INFO:	***** Run HMMER on gene sequences *****
# 2023-02-07 18:38:10 INFO:	Running 53 job(s) on hmmsearch, starting at 02/07/2023 18:38:10
# 2023-02-07 18:38:15 INFO:	[hmmsearch]	6 of 53 task(s) completed
# 2023-02-07 18:38:15 INFO:	[hmmsearch]	11 of 53 task(s) completed
# 2023-02-07 18:38:15 INFO:	[hmmsearch]	16 of 53 task(s) completed
# 2023-02-07 18:38:15 INFO:	[hmmsearch]	22 of 53 task(s) completed
# 2023-02-07 18:38:15 INFO:	[hmmsearch]	27 of 53 task(s) completed
# 2023-02-07 18:38:15 INFO:	[hmmsearch]	32 of 53 task(s) completed
# 2023-02-07 18:38:15 INFO:	[hmmsearch]	38 of 53 task(s) completed
# 2023-02-07 18:38:16 INFO:	[hmmsearch]	43 of 53 task(s) completed
# 2023-02-07 18:38:16 INFO:	[hmmsearch]	48 of 53 task(s) completed
# 2023-02-07 18:38:16 INFO:	[hmmsearch]	53 of 53 task(s) completed
# 2023-02-07 18:38:18 INFO:	Validating exons and removing overlapping matches
# 2023-02-07 18:38:20 INFO:	Results:	C:81.6%[S:79.6%,D:2.0%],F:9.0%,M:9.4%,n:255
#
# 2023-02-07 18:38:35 INFO:	eukaryota_odb10 selected
#
# 2023-02-07 18:38:35 INFO:	***** Searching tree for chosen lineage to find best taxonomic match *****
#
# 2023-02-07 18:38:35 INFO:	Extract markers...
# 2023-02-07 18:38:35 INFO:	Place the markers on the reference tree...
# 2023-02-07 18:38:35 INFO:	Running 1 job(s) on sepp, starting at 02/07/2023 18:38:35
# 2023-02-07 18:39:36 INFO:	[sepp]	1 of 1 task(s) completed
# 2023-02-07 18:39:39 INFO:	Lineage metazoa is selected, supported by 45 markers out of 88
# 2023-02-07 18:39:39 WARNING:	The file or folder /master/nplatt/sm_nanopore/results/busco/busco_downloads/lineages/metazoa_odb10 is not the last available version. To update all data files to the last version, add the parameter --update-data in your next run.
# 2023-02-07 18:39:39 INFO:	Running BUSCO using lineage dataset metazoa_odb10 (eukaryota, 2021-02-17)
# 2023-02-07 18:39:39 INFO:	Running 1 job(s) on bbtools, starting at 02/07/2023 18:39:39
# 2023-02-07 18:39:46 INFO:	[bbtools]	1 of 1 task(s) completed
# 2023-02-07 18:39:46 INFO:	Running 1 job(s) on metaeuk, starting at 02/07/2023 18:39:46
# 2023-02-07 18:46:25 INFO:	[metaeuk]	1 of 1 task(s) completed
# 2023-02-07 18:46:44 INFO:	***** Run HMMER on gene sequences *****
# 2023-02-07 18:46:44 INFO:	Running 954 job(s) on hmmsearch, starting at 02/07/2023 18:46:44
# 2023-02-07 18:46:50 INFO:	[hmmsearch]	96 of 954 task(s) completed
# 2023-02-07 18:46:50 INFO:	[hmmsearch]	191 of 954 task(s) completed
# 2023-02-07 18:46:51 INFO:	[hmmsearch]	287 of 954 task(s) completed
# 2023-02-07 18:46:51 INFO:	[hmmsearch]	382 of 954 task(s) completed
# 2023-02-07 18:46:51 INFO:	[hmmsearch]	478 of 954 task(s) completed
# 2023-02-07 18:46:51 INFO:	[hmmsearch]	573 of 954 task(s) completed
# 2023-02-07 18:46:52 INFO:	[hmmsearch]	668 of 954 task(s) completed
# 2023-02-07 18:46:52 INFO:	[hmmsearch]	764 of 954 task(s) completed
# 2023-02-07 18:46:52 INFO:	[hmmsearch]	859 of 954 task(s) completed
# 2023-02-07 18:46:53 INFO:	[hmmsearch]	954 of 954 task(s) completed
# 2023-02-07 18:46:56 INFO:	Extracting missing and fragmented buscos from the file refseq_db.faa...
# 2023-02-07 18:47:14 INFO:	Running 1 job(s) on metaeuk, starting at 02/07/2023 18:47:14
# 2023-02-07 18:59:10 INFO:	[metaeuk]	1 of 1 task(s) completed
# 2023-02-07 18:59:20 INFO:	***** Run HMMER on gene sequences *****
# 2023-02-07 18:59:20 INFO:	Running 375 job(s) on hmmsearch, starting at 02/07/2023 18:59:20
# 2023-02-07 18:59:26 INFO:	[hmmsearch]	38 of 375 task(s) completed
# 2023-02-07 18:59:26 INFO:	[hmmsearch]	75 of 375 task(s) completed
# 2023-02-07 18:59:27 INFO:	[hmmsearch]	113 of 375 task(s) completed
# 2023-02-07 18:59:27 INFO:	[hmmsearch]	150 of 375 task(s) completed
# 2023-02-07 18:59:28 INFO:	[hmmsearch]	188 of 375 task(s) completed
# 2023-02-07 18:59:28 INFO:	[hmmsearch]	225 of 375 task(s) completed
# 2023-02-07 18:59:29 INFO:	[hmmsearch]	263 of 375 task(s) completed
# 2023-02-07 18:59:29 INFO:	[hmmsearch]	300 of 375 task(s) completed
# 2023-02-07 18:59:29 INFO:	[hmmsearch]	338 of 375 task(s) completed
# 2023-02-07 18:59:30 INFO:	[hmmsearch]	375 of 375 task(s) completed
# 2023-02-07 18:59:37 INFO:	Validating exons and removing overlapping matches
# 2023-02-07 18:59:42 INFO:	Results:	C:63.8%[S:62.5%,D:1.3%],F:9.0%,M:27.2%,n:954
#
# 2023-02-07 19:00:02 INFO:
#
# 	--------------------------------------------------
# 	|Results from generic domain eukaryota_odb10      |
# 	--------------------------------------------------
# 	|C:81.6%[S:79.6%,D:2.0%],F:9.0%,M:9.4%,n:255      |
# 	|208	Complete BUSCOs (C)                       |
# 	|203	Complete and single-copy BUSCOs (S)       |
# 	|5	Complete and duplicated BUSCOs (D)        |
# 	|23	Fragmented BUSCOs (F)                     |
# 	|24	Missing BUSCOs (M)                        |
# 	|255	Total BUSCO groups searched               |
# 	--------------------------------------------------
#
# 	--------------------------------------------------
# 	|Results from dataset metazoa_odb10               |
# 	--------------------------------------------------
# 	|C:63.8%[S:62.5%,D:1.3%],F:9.0%,M:27.2%,n:954     |
# 	|608	Complete BUSCOs (C)                       |
# 	|596	Complete and single-copy BUSCOs (S)       |
# 	|12	Complete and duplicated BUSCOs (D)        |
# 	|86	Fragmented BUSCOs (F)                     |
# 	|260	Missing BUSCOs (M)                        |
# 	|954	Total BUSCO groups searched               |
# 	--------------------------------------------------
# 2023-02-07 19:00:02 INFO:	BUSCO analysis done with WARNING(s). Total running time: 2452 seconds
#
# ***** Summary of warnings: *****
# 2023-02-07 18:39:39 WARNING:busco.BuscoDownloadManager	The file or folder /master/nplatt/sm_nanopore/results/busco/busco_downloads/lineages/metazoa_odb10 is not the last available version. To update all data files to the last version, add the parameter --update-data in your next run.
#
# 2023-02-07 19:00:02 INFO:	Results written in /master/nplatt/sm_nanopore/results/busco/smle_pzq_er
# 2023-02-07 19:00:02 INFO:	For assistance with interpreting the results, please consult the userguide: https://busco.ezlab.org/busco_userguide.html
#
# 2023-02-07 19:00:02 INFO:	Visit this page https://gitlab.com/ezlab/busco#how-to-cite-busco to see how to cite BUSCO
# 2023-02-07 19:00:05 INFO:	***** Start a BUSCO v5.4.3 analysis, current time: 02/07/2023 19:00:05 *****
# 2023-02-07 19:00:05 INFO:	Configuring BUSCO with local environment
# 2023-02-07 19:00:05 INFO:	Mode is genome
# 2023-02-07 19:00:05 INFO:	Downloading information on latest versions of BUSCO data...
# 2023-02-07 19:00:08 INFO:	Input file is /master/nplatt/sm_nanopore/results/polish_assembly/smbre.assembly_rnd3.fasta
# 2023-02-07 19:00:08 INFO:	No lineage specified. Running lineage auto selector.
#
# 2023-02-07 19:00:08 INFO:	***** Starting Auto Select Lineage *****
# 	This process runs BUSCO on the generic lineage datasets for the domains archaea, bacteria and eukaryota. Once the optimal domain is selected, BUSCO automatically attempts to find the most appropriate BUSCO dataset to use based on phylogenetic placement.
# 	--auto-lineage-euk and --auto-lineage-prok are also available if you know your input assembly is, or is not, an eukaryote. See the user guide for more information.
# 	A reminder: Busco evaluations are valid when an appropriate dataset is used, i.e., the dataset belongs to the lineage of the species to test. Because of overlapping markers/spurious matches among domains, busco matches in another domain do not necessarily mean that your genome/proteome contains sequences from this domain. However, a high busco score in multiple domains might help you identify possible contaminations.
# 2023-02-07 19:00:08 INFO:	Running BUSCO using lineage dataset eukaryota_odb10 (eukaryota, 2020-09-10)
# 2023-02-07 19:00:08 INFO:	Running 1 job(s) on bbtools, starting at 02/07/2023 19:00:08
# 2023-02-07 19:00:12 INFO:	[bbtools]	1 of 1 task(s) completed
# 2023-02-07 19:00:13 INFO:	Running 1 job(s) on metaeuk, starting at 02/07/2023 19:00:13
# 2023-02-07 19:07:15 INFO:	[metaeuk]	1 of 1 task(s) completed
# 2023-02-07 19:07:28 INFO:	***** Run HMMER on gene sequences *****
# 2023-02-07 19:07:28 INFO:	Running 255 job(s) on hmmsearch, starting at 02/07/2023 19:07:28
# 2023-02-07 19:07:33 INFO:	[hmmsearch]	51 of 255 task(s) completed
# 2023-02-07 19:07:34 INFO:	[hmmsearch]	102 of 255 task(s) completed
# 2023-02-07 19:07:34 INFO:	[hmmsearch]	128 of 255 task(s) completed
# 2023-02-07 19:07:34 INFO:	[hmmsearch]	153 of 255 task(s) completed
# 2023-02-07 19:07:34 INFO:	[hmmsearch]	179 of 255 task(s) completed
# 2023-02-07 19:07:34 INFO:	[hmmsearch]	204 of 255 task(s) completed
# 2023-02-07 19:07:34 INFO:	[hmmsearch]	230 of 255 task(s) completed
# 2023-02-07 19:07:34 INFO:	[hmmsearch]	255 of 255 task(s) completed
# 2023-02-07 19:07:35 INFO:	Results:	C:82.8%[S:81.6%,D:1.2%],F:9.8%,M:7.4%,n:255
#
# 2023-02-07 19:07:35 INFO:	Extracting missing and fragmented buscos from the file refseq_db.faa...
# 2023-02-07 19:07:39 INFO:	Running 1 job(s) on metaeuk, starting at 02/07/2023 19:07:39
# 2023-02-07 19:17:24 INFO:	[metaeuk]	1 of 1 task(s) completed
# 2023-02-07 19:17:27 INFO:	***** Run HMMER on gene sequences *****
# 2023-02-07 19:17:27 INFO:	Running 44 job(s) on hmmsearch, starting at 02/07/2023 19:17:27
# 2023-02-07 19:17:33 INFO:	[hmmsearch]	5 of 44 task(s) completed
# 2023-02-07 19:17:33 INFO:	[hmmsearch]	9 of 44 task(s) completed
# 2023-02-07 19:17:33 INFO:	[hmmsearch]	14 of 44 task(s) completed
# 2023-02-07 19:17:33 INFO:	[hmmsearch]	18 of 44 task(s) completed
# 2023-02-07 19:17:33 INFO:	[hmmsearch]	23 of 44 task(s) completed
# 2023-02-07 19:17:33 INFO:	[hmmsearch]	27 of 44 task(s) completed
# 2023-02-07 19:17:33 INFO:	[hmmsearch]	31 of 44 task(s) completed
# 2023-02-07 19:17:33 INFO:	[hmmsearch]	36 of 44 task(s) completed
# 2023-02-07 19:17:33 INFO:	[hmmsearch]	40 of 44 task(s) completed
# 2023-02-07 19:17:33 INFO:	[hmmsearch]	44 of 44 task(s) completed
# 2023-02-07 19:17:35 INFO:	Validating exons and removing overlapping matches
# 2023-02-07 19:17:37 INFO:	Results:	C:83.2%[S:82.0%,D:1.2%],F:9.8%,M:7.0%,n:255
#
# 2023-02-07 19:17:50 INFO:	eukaryota_odb10 selected
#
# 2023-02-07 19:17:50 INFO:	***** Searching tree for chosen lineage to find best taxonomic match *****
#
# 2023-02-07 19:17:51 INFO:	Extract markers...
# 2023-02-07 19:17:51 INFO:	Place the markers on the reference tree...
# 2023-02-07 19:17:51 INFO:	Running 1 job(s) on sepp, starting at 02/07/2023 19:17:51
# 2023-02-07 19:18:54 INFO:	[sepp]	1 of 1 task(s) completed
# 2023-02-07 19:18:56 INFO:	Lineage metazoa is selected, supported by 48 markers out of 89
# 2023-02-07 19:18:56 WARNING:	The file or folder /master/nplatt/sm_nanopore/results/busco/busco_downloads/lineages/metazoa_odb10 is not the last available version. To update all data files to the last version, add the parameter --update-data in your next run.
# 2023-02-07 19:18:56 INFO:	Running BUSCO using lineage dataset metazoa_odb10 (eukaryota, 2021-02-17)
# 2023-02-07 19:18:56 INFO:	Running 1 job(s) on bbtools, starting at 02/07/2023 19:18:56
# 2023-02-07 19:19:03 INFO:	[bbtools]	1 of 1 task(s) completed
# 2023-02-07 19:19:03 INFO:	Running 1 job(s) on metaeuk, starting at 02/07/2023 19:19:03
# 2023-02-07 19:25:48 INFO:	[metaeuk]	1 of 1 task(s) completed
# 2023-02-07 19:26:03 INFO:	***** Run HMMER on gene sequences *****
# 2023-02-07 19:26:03 INFO:	Running 954 job(s) on hmmsearch, starting at 02/07/2023 19:26:03
# 2023-02-07 19:26:09 INFO:	[hmmsearch]	96 of 954 task(s) completed
# 2023-02-07 19:26:09 INFO:	[hmmsearch]	191 of 954 task(s) completed
# 2023-02-07 19:26:09 INFO:	[hmmsearch]	287 of 954 task(s) completed
# 2023-02-07 19:26:10 INFO:	[hmmsearch]	478 of 954 task(s) completed
# 2023-02-07 19:26:10 INFO:	[hmmsearch]	573 of 954 task(s) completed
# 2023-02-07 19:26:10 INFO:	[hmmsearch]	668 of 954 task(s) completed
# 2023-02-07 19:26:11 INFO:	[hmmsearch]	764 of 954 task(s) completed
# 2023-02-07 19:26:11 INFO:	[hmmsearch]	764 of 954 task(s) completed
# 2023-02-07 19:26:11 INFO:	[hmmsearch]	859 of 954 task(s) completed
# 2023-02-07 19:26:12 INFO:	[hmmsearch]	954 of 954 task(s) completed
# 2023-02-07 19:26:15 INFO:	Extracting missing and fragmented buscos from the file refseq_db.faa...
# 2023-02-07 19:26:31 INFO:	Running 1 job(s) on metaeuk, starting at 02/07/2023 19:26:31
# 2023-02-07 19:38:05 INFO:	[metaeuk]	1 of 1 task(s) completed
# 2023-02-07 19:38:10 INFO:	***** Run HMMER on gene sequences *****
# 2023-02-07 19:38:10 INFO:	Running 335 job(s) on hmmsearch, starting at 02/07/2023 19:38:10
# 2023-02-07 19:38:16 INFO:	[hmmsearch]	34 of 335 task(s) completed
# 2023-02-07 19:38:16 INFO:	[hmmsearch]	67 of 335 task(s) completed
# 2023-02-07 19:38:16 INFO:	[hmmsearch]	101 of 335 task(s) completed
# 2023-02-07 19:38:17 INFO:	[hmmsearch]	134 of 335 task(s) completed
# 2023-02-07 19:38:17 INFO:	[hmmsearch]	168 of 335 task(s) completed
# 2023-02-07 19:38:17 INFO:	[hmmsearch]	201 of 335 task(s) completed
# 2023-02-07 19:38:17 INFO:	[hmmsearch]	235 of 335 task(s) completed
# 2023-02-07 19:38:18 INFO:	[hmmsearch]	268 of 335 task(s) completed
# 2023-02-07 19:38:18 INFO:	[hmmsearch]	302 of 335 task(s) completed
# 2023-02-07 19:38:18 INFO:	[hmmsearch]	335 of 335 task(s) completed
# 2023-02-07 19:38:27 INFO:	Validating exons and removing overlapping matches
# 2023-02-07 19:38:32 INFO:	Results:	C:66.6%[S:65.3%,D:1.3%],F:7.4%,M:26.0%,n:954
#
# 2023-02-07 19:38:51 INFO:
#
# 	--------------------------------------------------
# 	|Results from generic domain eukaryota_odb10      |
# 	--------------------------------------------------
# 	|C:83.2%[S:82.0%,D:1.2%],F:9.8%,M:7.0%,n:255      |
# 	|212	Complete BUSCOs (C)                       |
# 	|209	Complete and single-copy BUSCOs (S)       |
# 	|3	Complete and duplicated BUSCOs (D)        |
# 	|25	Fragmented BUSCOs (F)                     |
# 	|18	Missing BUSCOs (M)                        |
# 	|255	Total BUSCO groups searched               |
# 	--------------------------------------------------
#
# 	--------------------------------------------------
# 	|Results from dataset metazoa_odb10               |
# 	--------------------------------------------------
# 	|C:66.6%[S:65.3%,D:1.3%],F:7.4%,M:26.0%,n:954     |
# 	|635	Complete BUSCOs (C)                       |
# 	|623	Complete and single-copy BUSCOs (S)       |
# 	|12	Complete and duplicated BUSCOs (D)        |
# 	|71	Fragmented BUSCOs (F)                     |
# 	|248	Missing BUSCOs (M)                        |
# 	|954	Total BUSCO groups searched               |
# 	--------------------------------------------------
# 2023-02-07 19:38:51 INFO:	BUSCO analysis done with WARNING(s). Total running time: 2323 seconds
#
# ***** Summary of warnings: *****
# 2023-02-07 19:18:56 WARNING:busco.BuscoDownloadManager	The file or folder /master/nplatt/sm_nanopore/results/busco/busco_downloads/lineages/metazoa_odb10 is not the last available version. To update all data files to the last version, add the parameter --update-data in your next run.
#
# 2023-02-07 19:38:51 INFO:	Results written in /master/nplatt/sm_nanopore/results/busco/smbre
# 2023-02-07 19:38:51 INFO:	For assistance with interpreting the results, please consult the userguide: https://busco.ezlab.org/busco_userguide.html
#
# 2023-02-07 19:38:51 INFO:	Visit this page https://gitlab.com/ezlab/busco#how-to-cite-busco to see how to cite BUSCO
# 2023-02-07 19:38:54 INFO:	***** Start a BUSCO v5.4.3 analysis, current time: 02/07/2023 19:38:54 *****
# 2023-02-07 19:38:54 INFO:	Configuring BUSCO with local environment
# 2023-02-07 19:38:54 INFO:	Mode is genome
# 2023-02-07 19:38:54 INFO:	Downloading information on latest versions of BUSCO data...
# 2023-02-07 19:38:57 INFO:	Input file is /master/nplatt/sm_nanopore/results/polish_assembly/smeg.assembly_rnd3.fasta
# 2023-02-07 19:38:57 INFO:	No lineage specified. Running lineage auto selector.
#
# 2023-02-07 19:38:57 INFO:	***** Starting Auto Select Lineage *****
# 	This process runs BUSCO on the generic lineage datasets for the domains archaea, bacteria and eukaryota. Once the optimal domain is selected, BUSCO automatically attempts to find the most appropriate BUSCO dataset to use based on phylogenetic placement.
# 	--auto-lineage-euk and --auto-lineage-prok are also available if you know your input assembly is, or is not, an eukaryote. See the user guide for more information.
# 	A reminder: Busco evaluations are valid when an appropriate dataset is used, i.e., the dataset belongs to the lineage of the species to test. Because of overlapping markers/spurious matches among domains, busco matches in another domain do not necessarily mean that your genome/proteome contains sequences from this domain. However, a high busco score in multiple domains might help you identify possible contaminations.
# 2023-02-07 19:38:59 INFO:	Running BUSCO using lineage dataset eukaryota_odb10 (eukaryota, 2020-09-10)
# 2023-02-07 19:38:59 INFO:	Running 1 job(s) on bbtools, starting at 02/07/2023 19:38:59
# 2023-02-07 19:39:04 INFO:	[bbtools]	1 of 1 task(s) completed
# 2023-02-07 19:39:04 INFO:	Running 1 job(s) on metaeuk, starting at 02/07/2023 19:39:04
# 2023-02-07 19:45:51 INFO:	[metaeuk]	1 of 1 task(s) completed
# 2023-02-07 19:46:09 INFO:	***** Run HMMER on gene sequences *****
# 2023-02-07 19:46:09 INFO:	Running 255 job(s) on hmmsearch, starting at 02/07/2023 19:46:09
# 2023-02-07 19:46:14 INFO:	[hmmsearch]	26 of 255 task(s) completed
# 2023-02-07 19:46:14 INFO:	[hmmsearch]	51 of 255 task(s) completed
# 2023-02-07 19:46:14 INFO:	[hmmsearch]	77 of 255 task(s) completed
# 2023-02-07 19:46:15 INFO:	[hmmsearch]	102 of 255 task(s) completed
# 2023-02-07 19:46:15 INFO:	[hmmsearch]	128 of 255 task(s) completed
# 2023-02-07 19:46:15 INFO:	[hmmsearch]	153 of 255 task(s) completed
# 2023-02-07 19:46:15 INFO:	[hmmsearch]	179 of 255 task(s) completed
# 2023-02-07 19:46:15 INFO:	[hmmsearch]	204 of 255 task(s) completed
# 2023-02-07 19:46:15 INFO:	[hmmsearch]	230 of 255 task(s) completed
# 2023-02-07 19:46:16 INFO:	[hmmsearch]	255 of 255 task(s) completed
# 2023-02-07 19:46:16 INFO:	Results:	C:80.8%[S:79.2%,D:1.6%],F:10.2%,M:9.0%,n:255
#
# 2023-02-07 19:46:16 INFO:	Extracting missing and fragmented buscos from the file refseq_db.faa...
# 2023-02-07 19:46:21 INFO:	Running 1 job(s) on metaeuk, starting at 02/07/2023 19:46:21
# 2023-02-07 19:57:13 INFO:	[metaeuk]	1 of 1 task(s) completed
# 2023-02-07 19:57:16 INFO:	***** Run HMMER on gene sequences *****
# 2023-02-07 19:57:16 INFO:	Running 49 job(s) on hmmsearch, starting at 02/07/2023 19:57:16
# 2023-02-07 19:57:21 INFO:	[hmmsearch]	5 of 49 task(s) completed
# 2023-02-07 19:57:21 INFO:	[hmmsearch]	10 of 49 task(s) completed
# 2023-02-07 19:57:22 INFO:	[hmmsearch]	15 of 49 task(s) completed
# 2023-02-07 19:57:22 INFO:	[hmmsearch]	20 of 49 task(s) completed
# 2023-02-07 19:57:22 INFO:	[hmmsearch]	25 of 49 task(s) completed
# 2023-02-07 19:57:22 INFO:	[hmmsearch]	30 of 49 task(s) completed
# 2023-02-07 19:57:22 INFO:	[hmmsearch]	35 of 49 task(s) completed
# 2023-02-07 19:57:22 INFO:	[hmmsearch]	40 of 49 task(s) completed
# 2023-02-07 19:57:22 INFO:	[hmmsearch]	45 of 49 task(s) completed
# 2023-02-07 19:57:22 INFO:	[hmmsearch]	49 of 49 task(s) completed
# 2023-02-07 19:57:24 INFO:	Validating exons and removing overlapping matches
# 2023-02-07 19:57:26 INFO:	Results:	C:82.0%[S:80.4%,D:1.6%],F:10.2%,M:7.8%,n:255
#
# 2023-02-07 19:57:41 INFO:	eukaryota_odb10 selected
#
# 2023-02-07 19:57:41 INFO:	***** Searching tree for chosen lineage to find best taxonomic match *****
#
# 2023-02-07 19:57:41 INFO:	Extract markers...
# 2023-02-07 19:57:41 INFO:	Place the markers on the reference tree...
# 2023-02-07 19:57:41 INFO:	Running 1 job(s) on sepp, starting at 02/07/2023 19:57:41
# 2023-02-07 19:58:43 INFO:	[sepp]	1 of 1 task(s) completed
# 2023-02-07 19:58:45 INFO:	Lineage metazoa is selected, supported by 43 markers out of 85
# 2023-02-07 19:58:45 WARNING:	The file or folder /master/nplatt/sm_nanopore/results/busco/busco_downloads/lineages/metazoa_odb10 is not the last available version. To update all data files to the last version, add the parameter --update-data in your next run.
# 2023-02-07 19:58:46 INFO:	Running BUSCO using lineage dataset metazoa_odb10 (eukaryota, 2021-02-17)
# 2023-02-07 19:58:46 INFO:	Running 1 job(s) on bbtools, starting at 02/07/2023 19:58:46
# 2023-02-07 19:58:52 INFO:	[bbtools]	1 of 1 task(s) completed
# 2023-02-07 19:58:52 INFO:	Running 1 job(s) on metaeuk, starting at 02/07/2023 19:58:52
# 2023-02-07 20:05:01 INFO:	[metaeuk]	1 of 1 task(s) completed
# 2023-02-07 20:05:22 INFO:	***** Run HMMER on gene sequences *****
# 2023-02-07 20:05:22 INFO:	Running 954 job(s) on hmmsearch, starting at 02/07/2023 20:05:22
# 2023-02-07 20:05:28 INFO:	[hmmsearch]	96 of 954 task(s) completed
# 2023-02-07 20:05:28 INFO:	[hmmsearch]	287 of 954 task(s) completed
# 2023-02-07 20:05:29 INFO:	[hmmsearch]	382 of 954 task(s) completed
# 2023-02-07 20:05:29 INFO:	[hmmsearch]	382 of 954 task(s) completed
# 2023-02-07 20:05:29 INFO:	[hmmsearch]	478 of 954 task(s) completed
# 2023-02-07 20:05:29 INFO:	[hmmsearch]	573 of 954 task(s) completed
# 2023-02-07 20:05:29 INFO:	[hmmsearch]	668 of 954 task(s) completed
# 2023-02-07 20:05:30 INFO:	[hmmsearch]	764 of 954 task(s) completed
# 2023-02-07 20:05:30 INFO:	[hmmsearch]	859 of 954 task(s) completed
# 2023-02-07 20:05:31 INFO:	[hmmsearch]	954 of 954 task(s) completed
# 2023-02-07 20:05:35 INFO:	Extracting missing and fragmented buscos from the file refseq_db.faa...
# 2023-02-07 20:05:50 INFO:	Running 1 job(s) on metaeuk, starting at 02/07/2023 20:05:50
# 2023-02-07 20:17:10 INFO:	[metaeuk]	1 of 1 task(s) completed
# 2023-02-07 20:17:22 INFO:	***** Run HMMER on gene sequences *****
# 2023-02-07 20:17:22 INFO:	Running 331 job(s) on hmmsearch, starting at 02/07/2023 20:17:22
# 2023-02-07 20:17:28 INFO:	[hmmsearch]	34 of 331 task(s) completed
# 2023-02-07 20:17:28 INFO:	[hmmsearch]	67 of 331 task(s) completed
# 2023-02-07 20:17:29 INFO:	[hmmsearch]	100 of 331 task(s) completed
# 2023-02-07 20:17:29 INFO:	[hmmsearch]	133 of 331 task(s) completed
# 2023-02-07 20:17:29 INFO:	[hmmsearch]	166 of 331 task(s) completed
# 2023-02-07 20:17:30 INFO:	[hmmsearch]	199 of 331 task(s) completed
# 2023-02-07 20:17:30 INFO:	[hmmsearch]	232 of 331 task(s) completed
# 2023-02-07 20:17:30 INFO:	[hmmsearch]	265 of 331 task(s) completed
# 2023-02-07 20:17:31 INFO:	[hmmsearch]	298 of 331 task(s) completed
# 2023-02-07 20:17:31 INFO:	[hmmsearch]	331 of 331 task(s) completed
# 2023-02-07 20:17:39 INFO:	Validating exons and removing overlapping matches
# 2023-02-07 20:17:44 INFO:	Results:	C:67.4%[S:66.4%,D:1.0%],F:7.4%,M:25.2%,n:954
#
# 2023-02-07 20:18:05 INFO:
#
# 	--------------------------------------------------
# 	|Results from generic domain eukaryota_odb10      |
# 	--------------------------------------------------
# 	|C:82.0%[S:80.4%,D:1.6%],F:10.2%,M:7.8%,n:255     |
# 	|209	Complete BUSCOs (C)                       |
# 	|205	Complete and single-copy BUSCOs (S)       |
# 	|4	Complete and duplicated BUSCOs (D)        |
# 	|26	Fragmented BUSCOs (F)                     |
# 	|20	Missing BUSCOs (M)                        |
# 	|255	Total BUSCO groups searched               |
# 	--------------------------------------------------
#
# 	--------------------------------------------------
# 	|Results from dataset metazoa_odb10               |
# 	--------------------------------------------------
# 	|C:67.4%[S:66.4%,D:1.0%],F:7.4%,M:25.2%,n:954     |
# 	|643	Complete BUSCOs (C)                       |
# 	|633	Complete and single-copy BUSCOs (S)       |
# 	|10	Complete and duplicated BUSCOs (D)        |
# 	|71	Fragmented BUSCOs (F)                     |
# 	|240	Missing BUSCOs (M)                        |
# 	|954	Total BUSCO groups searched               |
# 	--------------------------------------------------
# 2023-02-07 20:18:05 INFO:	BUSCO analysis done with WARNING(s). Total running time: 2347 seconds
#
# ***** Summary of warnings: *****
# 2023-02-07 19:58:45 WARNING:busco.BuscoDownloadManager	The file or folder /master/nplatt/sm_nanopore/results/busco/busco_downloads/lineages/metazoa_odb10 is not the last available version. To update all data files to the last version, add the parameter --update-data in your next run.
#
# 2023-02-07 20:18:05 INFO:	Results written in /master/nplatt/sm_nanopore/results/busco/smeg
# 2023-02-07 20:18:05 INFO:	For assistance with interpreting the results, please consult the userguide: https://busco.ezlab.org/busco_userguide.html
#
# 2023-02-07 20:18:05 INFO:	Visit this page https://gitlab.com/ezlab/busco#how-to-cite-busco to see how to cite BUSCO

# %% [markdown]
# ## genome quality

# %%
for sample in samples:
    assembly = "{}/polish_assembly/{}.assembly_rnd3.fasta".format(proj_dir, sample)
    ./JupiterPlot/jupiter t=48 name={sample} ng=85 ref={ref_fas} fa={assembly}

# %% [markdown]
# ## Grave Yard

# %%
conda activate sm_ont-process_reads

cd /master/nplatt/sm_nanopore

cd sm_nanopore/results/nanofilt
3
 ~/anaconda3/envs/sm_ont-process_reads/bin/flye --nano-cor ../read_correction_canu/${SAMPLE}/${SAMPLE}.correctedReads.fasta.gz -g 385m -t 96  -i 3 -o ${SAMPLE} >${SAMPLE}.canu.log 2>&1 &

conda activate repeatmasker
RepeatMasker \
    -pa 12 \
    -lib ../repeatmodeler/Smansoni_v7-families.fa \
    -gff \
    -s \
    -dir $(pwd) \
    -small \
    -x \
    $REF



SmOR_Female_6_02_22_vSM_V9_sorted.vcf
schisto_pairs_04132022_vSM_V9_sorted.vcf
SmEG_Female_5_25_22_vSM_V9_sorted.vcf

bcftools filter \
    -sLOWFREQ_SMALL -i' (SVLEN<-500 || SVLEN>500) && AF>0.75' \
    schisto_pairs_04132022_vSM_V9_sorted.vcf \
    | vcftools \
        --remove-filtered-all \
        --vcf - \
        --recode \
        --recode-INFO-all \
        --stdout \
        >smle-pzq-es_filtered.vcf

bedtools intersect \
    -c \
    -b smle-pzq-es_filtered.vcf \
    -a ../lift/v9.bed \
    >smle-pzq-es_intersect.bed


bcftools filter \
    -sLOWFREQ_SMALL -i' (SVLEN<-200 || SVLEN>200)' \
    schisto_pairs_04132022_vSM_V9_sorted.vcf \
    | vcftools \
        --remove-filtered-all \
        --vcf - \
        --recode \
        --recode-INFO-all \
        --stdout

#############################################################################################

#genrate reads
art_illumina \
    --len 150 \
    --fcov 100 \
    --errfree \
    -na \
    --in SM_V9.fa \
    --out sm_v9_illumina \
    >sm_v9_illumina.log 2>&1 &

nanosim-h \
    --perfect \
    -o sm_v9_ont \
    -n 5000000 \
    SM_V9.fa \
    >sm_v9_ont.log 2>&1 &

#convert to fasta
sed -n '1~4s/^@/>/p;2~4p' sm_v9_illumina.fq > sm_v9_illumina.fa

#make sure amount of data is similar
echo sm_v9_ont.fa $(cat sm_v9_ont.fa | paste  - - | cut -f2 | wc -c) >>counts &
echo sm_v9_illumina.fa $(cat sm_v9_illumina.fa | paste  - - | cut -f2 | wc -c) >>counts &




#map reads (perfectly and unambiguosly) back to the reference
for SAMPLE in sm_v9_illumina sm_v9_ont; do
    bbmap.sh \
        ref=SM_V9.fa \
        perfectmode=t \
        threads=48 \
        ambiguous=toss \
        in=${SAMPLE}.fa \
        overwrite=t \
        out=${SAMPLE}.sam \
        mappedonly=t \
        >${SAMPLE}.bbmap.log 2>&1 &
done


#calculate coverage
for SAMPLE in sm_v9_illumina sm_v9_ont; do

    echo $SAMPLE
    echo "...sort"
    samtools view -b -F 4 ${SAMPLE}.sam | samtools sort >${SAMPLE}.bam
    echo "...idx"
    samtools index ${SAMPLE}.bam
    echo "...cov"
    mosdepth \
        --threads 4 \
        ${SAMPLE} \
        ${SAMPLE}.bam
done

#how much is inaccessible per read type
for SAMPLE in sm_v9_illumina sm_v9_ont; do

    MB=$(zcat ${SAMPLE}.per-base.bed.gz | awk '{if ($4<=2) SUM+=$3-$2} END {print SUM/1000000}')
    echo -e $SAMPLE"\t"$MB

done

art_illumina \
--paired \
--len 150 \
--fcov 10 \
--mflen 300 \
--sdev 80 \
-na \
--in SM_V9.fa \
--out sm_v9_wes


bbmap.sh \
    ref=SM_V9.fa \
    threads=48 \
    ambiguous=toss \
    in=sm_v9_wes1.fq \
    in2=sm_v9_wes2.fq \
    samestrandpairs=t \
    killbadpairs=t \
    overwrite=t \
    out=sm_v9_wes.sam \
    mappedonly=t \
    ignorebadquality=t

samtools view -b -F 4 sm_v9_wes.sam | samtools sort >sm_v9_wes.bam
samtools index sm_v9_wes.bam

mosdepth \
    --threads 4 \
    sm_v9_wes \
    sm_v9_wes.bam



zcat sm_v9_wes.per-base.bed.gz | awk '{if ($4>=12) SUM+=$3-$2} END {print SUM/1000000}'
zcat sm_v9_wes.per-base.bed.gz | awk '{if ($4<=2) SUM+=$3-$2} END {print SUM/1000000}'








sed -i 's/SM_V9_1/HE601624.3/' sm_v9.gff3
sed -i 's/SM_V9_2/HE601625.3/' sm_v9.gff3
sed -i 's/SM_V9_3/HE601626.3/' sm_v9.gff3
sed -i 's/SM_V9_4/HE601627.3/' sm_v9.gff3
sed -i 's/SM_V9_5/HE601628.3/' sm_v9.gff3
sed -i 's/SM_V9_6/HE601629.3/' sm_v9.gff3



bedtools intersect \
    -wb \
    -a smle-pzq-es_filtered.vcf \
    -b sm_v9.gff3





bcftools filter \
    -sLOWFREQ_SMALL -i' (SVLEN<-500 || SVLEN>500) && AF>0.75' \
    schisto_pairs_04132022_vSM_V9_sorted.vcf \
    | vcftools \
        --remove-filtered-all \
        --vcf - \
        --recode \
        --recode-INFO-all \
        --stdout \
        >smle-pzq-es_filtered.vcf

bedtools intersect \
    -c \
    -b smle-pzq-es_filtered.vcf \
    -a ../lift/v9.bed








cp ../cutesv/sm_v9.gff3 .
awk '{if ($3=="exon") print $0}' sm_v9.gff3 >sm_v9_exons.gff3
cut -f1 -d";" sm_v9_exons.gff3 | cut -f1,4,5,9 | sed 's/ID=exon://' >sm_v9_exons.bed
bedtools intersect -a sm_v9_exons.bed  -b qtls_v9.bed >qtl_exons.bed


bedtools intersect -wb -a qtls_v9.bed -b smeg_filtered.vcf  >smeg_qtl_snvs.vcf
bedtools intersect -wa -b smeg_qtl_snvs.vcf -a qtl_exons.bed   | sort -u -k4,4 > smeg_snvs_in_qtl_exons.bed
bedtools intersect -c -b smeg_snvs_in_qtl_exons.bed -a qtls_v9.bed
bedtools intersect -wb -b smeg_snvs_in_qtl_exons.bed -a qtls_v9.bed | cut -f4,8 | cut -f1 -d"." | sort -u -k2,2 | cut -f1 | sort | uniq -c

bedtools intersect -wb -a qtls_v9.bed -b smor_filtered.vcf  >smor_qtl_snvs.vcf
bedtools intersect -wa -b smor_qtl_snvs.vcf -a qtl_exons.bed   | sort -u -k4,4 > smor_snvs_in_qtl_exons.bed
bedtools intersect -c -b smor_snvs_in_qtl_exons.bed -a qtls_v9.bed
bedtools intersect -wb -b smor_snvs_in_qtl_exons.bed -a qtls_v9.bed | cut -f4,8 | cut -f1 -d"." | sort -u -k2,2 | cut -f1 | sort | uniq -c


bedtools intersect -wb -a qtls_v9.bed -b smle-pzq-es_filtered.vcf  >smle-pzq-es_qtl_snvs.vcf
bedtools intersect -wa -b smle-pzq-es_qtl_snvs.vcf -a qtl_exons.bed   | sort -u -k4,4 > smle-pzq-es_snvs_in_qtl_exons.bed
bedtools intersect -c -b smle-pzq-es_snvs_in_qtl_exons.bed -a qtls_v9.bed
bedtools intersect -wb -b smle-pzq-es_snvs_in_qtl_exons.bed -a qtls_v9.bed | cut -f4,8 | cut -f1 -d"." | sort -u -k2,2 | cut -f1 | sort | uniq -c









nanosim-h --perfect -o sm_v9_ont_reads -n 500000 SM_V9.fa


    minimap2 \
        -a \
        -o sm_v9_ont.sam \
        -t 48 \
        -x map-ont \
        SM_V9.fa \
        sm_v9_ont_reads.fa



samtools view -b -F 4 sm_v9_ont.sam | samtools sort >sm_v9_ont.bam

samtools index sm_v9_ont.bam

mosdepth \
    --threads 4 \
    sm_v9_ont \
    sm_v9_ont.bam

zcat sm_v9_ont.per-base.bed.gz | awk '{if ($4>=12) SUM+=$3-$2} END {print SUM/1000000}'
zcat sm_v9_ont.per-base.bed.gz | awk '{if ($4<=2) SUM+=$3-$2} END {print SUM/1000000}'


bbmap.sh \
    ref=SM_V9.fa \
    threads=48 \
    ambiguous=toss \
    in=sm_v9_ont_reads.fa \
    overwrite=t \
    out=sm_v9_ont_bbmap.sam \
    mappedonly=t \
    ignorebadquality=t

bbmap.sh \
    ref=SM_V9.fa \
    perfectmode=t \
    threads=48 \
    ambiguous=toss \
    in=sm_v9_ont_reads.fa \
    overwrite=t \
    out=sm_v9_ont_bbmap.sam \
    mappedonly=t


samtools view -b -F 4 sm_v9_ont_bbmap.sam | samtools sort >sm_v9_ont_bbmap.bam
samtools index sm_v9_ont_bbmap.bam

mosdepth \
    --threads 4 \
    sm_v9_ont_bbmap \
    sm_v9_ont_bbmap.bam

zcat sm_v9_ont_bbmap.per-base.bed.gz | awk '{if ($4>=12) SUM+=$3-$2} END {print SUM/1000000}'
zcat sm_v9_ont_bbmap.per-base.bed.gz | awk '{if ($4<=2) SUM+=$3-$2} END {print SUM/1000000}'

RepeatMasker -qq -pa 48 -nolow -norna -dir . -gff -lib sm_v7_tes.fas SM_V9.fa

SmEG_Female_5_25_22
schisto_pairs_04132022  ../cutesv/SmOR_Female_6_02_22_vSM_V9_sorted.vcf

for VCF in $(ls ../cutesv/*_vSM_V9_sorted.vcf); do 

bcftools filter \
    -sLOWFREQ_SMALL -i' (SVLEN<-500 || SVLEN>500)' \
    ../cutesv/schisto_pairs_04132022_vSM_V9_sorted.vcf \
    | vcftools \
        --remove-filtered-all \
        --vcf - \
        --recode \
        --recode-INFO-all \
        --stdout \
        >smle-pze-es_bigsvs.vcf

bcftools filter \
    -sLOWFREQ_SMALL -i' (SVLEN<-500 || SVLEN>500)' \
    ../cutesv/SmEG_Female_5_25_22_vSM_V9_sorted.vcf \
    | vcftools \
        --remove-filtered-all \
        --vcf - \
        --recode \
        --recode-INFO-all \
        --stdout \
        >smeg_bigsvs.vcf

bcftools filter \
    -sLOWFREQ_SMALL -i' (SVLEN<-500 || SVLEN>500)' \
    ../cutesv/SmOR_Female_6_02_22_vSM_V9_sorted.vcf \
    | vcftools \
        --remove-filtered-all \
        --vcf - \
        --recode \
        --recode-INFO-all \
        --stdout \
        >smor_bigsvs.vcf

   396,000,000
39,777,694,771
